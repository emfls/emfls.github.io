# %%
# !pip install deep-translator beautifulsoup4
# Out:
# Collecting deep-translator
#   Downloading deep_translator-1.11.4-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (4.12.3)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from deep-translator) (2.32.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2024.8.30)
# Downloading deep_translator-1.11.4-py3-none-any.whl (42 kB)
# Installing collected packages: deep-translator
# Successfully installed deep-translator-1.11.4
# [notice] A new release of pip is available: 24.2 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import glob
from deep_translator import GoogleTranslator
from bs4 import BeautifulSoup, Comment
import time
import re
import json

language_ = "ja"

def clean_html_formatting(html_str):
    """
    HTML 포맷팅 정리 함수
    - DOCTYPE 하단 불필요한 'html' 텍스트 제거
    """
    doctype_match = re.search(r'<!DOCTYPE[^>]*>', html_str, re.IGNORECASE)
    doctype = doctype_match.group(0) if doctype_match else ''
    after_doctype = html_str[doctype_match.end():] if doctype_match else html_str
    after_doctype = re.sub(r'^\s*html\s*\n', '', after_doctype, flags=re.IGNORECASE)
    if doctype:
        cleaned_html = doctype + '\n' + after_doctype.lstrip()
    else:
        cleaned_html = after_doctype
    return cleaned_html

def translate_json_content(json_str, translator):
    """
    JSON 구조화된 데이터 내 텍스트 번역
    """
    try:
        data = json.loads(json_str)
        
        def translate_recursive(obj):
            if isinstance(obj, dict):
                for key, value in obj.items():
                    if isinstance(value, str) and value.strip():
                        # 영어가 아닌 텍스트만 번역
                        if not is_english_text(value):
                            try:
                                obj[key] = translator.translate(value)
                            except:
                                pass
                    elif isinstance(value, (dict, list)):
                        translate_recursive(value)
            elif isinstance(obj, list):
                for i, item in enumerate(obj):
                    if isinstance(item, str) and item.strip():
                        if not is_english_text(item):
                            try:
                                obj[i] = translator.translate(item)
                            except:
                                pass
                    elif isinstance(item, (dict, list)):
                        translate_recursive(item)
        
        translate_recursive(data)
        return json.dumps(data, ensure_ascii=False, indent=16)
    except:
        return json_str

def is_english_text(text):
    """
    텍스트가 영어인지 간단히 판단
    """
    if not text.strip():
        return True
    
    # URL, 이메일, 특수 코드는 번역하지 않음
    if any(pattern in text.lower() for pattern in ['http', 'www.', '@', '.com', '.html', 'gtag', 'dataLayer']):
        return True
    
    # 숫자만 있는 경우
    if text.strip().replace(' ', '').replace('-', '').replace('/', '').isdigit():
        return True
    
    # 한글이 포함된 경우 한국어로 판단
    if any('\uac00' <= char <= '\ud7af' for char in text):
        return False
    
    return True

def translate_html_complete(input_folder, output_folder, source_lang='auto', target_lang=language_):
    """
    HTML 파일들을 완전히 번역하는 함수 (메타태그, JSON 데이터 포함)
    """
    os.makedirs(output_folder, exist_ok=True)
    translator = GoogleTranslator(source=source_lang, target=target_lang)
    html_files = glob.glob(os.path.join(input_folder, '*.html'))
    
    if not html_files:
        print(f"'{input_folder}' 폴더에 HTML 파일이 없습니다.")
        return
    
    print(f"총 {len(html_files)}개의 HTML 파일을 발견했습니다.")
    
    for i, html_file in enumerate(html_files):
        filename = os.path.basename(html_file)
        output_file = os.path.join(output_folder, filename)
        
        if os.path.exists(output_file):
            print(f"⏭️  {filename} - 이미 번역되어 건너뜀")
            continue
        
        print(f"🔄 번역 중... ({i+1}/{len(html_files)}): {filename}")
        
        try:
            with open(html_file, 'r', encoding='utf-8') as f:
                original_content = f.read()
            
            # DOCTYPE 선언 추출 및 보존
            doctype_match = re.search(r'<!DOCTYPE[^>]*>', original_content, re.IGNORECASE)
            original_doctype = doctype_match.group(0) if doctype_match else None
            
            # BeautifulSoup으로 파싱
            soup = BeautifulSoup(original_content, 'html.parser')
            
            translated_count = 0
            
            # 1. 메타 태그 번역
            meta_tags = soup.find_all('meta')
            for meta in meta_tags:
                if meta.get('content') and not is_english_text(meta.get('content')):
                    try:
                        translated_content = translator.translate(meta.get('content'))
                        meta['content'] = translated_content
                        translated_count += 1
                        print(f"   🏷️  메타태그 번역: {meta.get('name') or meta.get('property')}")
                    except:
                        pass
            
            # 2. JSON-LD 구조화된 데이터 번역
            json_scripts = soup.find_all('script', type='application/ld+json')
            for script in json_scripts:
                if script.string:
                    translated_json = translate_json_content(script.string, translator)
                    script.string = translated_json
                    print(f"   📊 JSON-LD 데이터 번역 완료")
            
            # 3. JavaScript 주석 및 문자열 번역
            js_scripts = soup.find_all('script', type=lambda x: x != 'application/ld+json')
            for script in js_scripts:
                if script.string:
                    js_content = script.string
                    # JavaScript 주석 내 한국어 번역
                    comment_pattern = r'//\s*(.+)'
                    matches = re.findall(comment_pattern, js_content)
                    for match in matches:
                        if not is_english_text(match):
                            try:
                                translated_comment = translator.translate(match)
                                js_content = js_content.replace(match, translated_comment)
                                translated_count += 1
                            except:
                                pass
                    
                    # JavaScript 문자열 내 한국어 번역
                    string_pattern = r'"([^"]*[가-힣]+[^"]*)"'
                    matches = re.findall(string_pattern, js_content)
                    for match in matches:
                        if not is_english_text(match):
                            try:
                                translated_string = translator.translate(match)
                                js_content = js_content.replace(f'"{match}"', f'"{translated_string}"')
                                translated_count += 1
                            except:
                                pass
                    
                    script.string = js_content
            
            # 4. 일반 텍스트 노드 번역
            text_nodes = soup.find_all(text=True)
            for text in text_nodes:
                if isinstance(text, Comment):
                    print(f"   💬 주석 건너뜀: {str(text).strip()[:30]}...")
                    continue
                
                if (text.strip() and 
                    text.parent.name not in ['script', 'style', 'meta'] and
                    not isinstance(text, Comment) and
                    not is_english_text(text.strip())):
                    try:
                        translated = translator.translate(text.strip())
                        text.replace_with(translated)
                        translated_count += 1
                    except Exception as e:
                        print(f"   ⚠️  텍스트 번역 실패: {text.strip()[:30]}... - {e}")
                        continue
            
            # 5. 속성값 번역 (alt, title, placeholder 등)
            for tag in soup.find_all():
                for attr in ['alt', 'title', 'placeholder', 'aria-label']:
                    if tag.get(attr) and not is_english_text(tag.get(attr)):
                        try:
                            translated_attr = translator.translate(tag.get(attr))
                            tag[attr] = translated_attr
                            translated_count += 1
                            print(f"   🔖 속성 번역: {attr}")
                        except:
                            pass
            
            # HTML 문자열로 변환
            translated_html = str(soup)
            
            # 원본 DOCTYPE 복원
            if original_doctype:
                translated_html = re.sub(r'<!DOCTYPE[^>]*>\s*', '', translated_html, flags=re.IGNORECASE)
                translated_html = original_doctype + '\n' + translated_html
                print(f"   📄 DOCTYPE 보존: {original_doctype}")
            
            # HTML 포맷팅 정리
            translated_html = clean_html_formatting(translated_html)
            
            # 번역된 파일 저장
            with open(output_file, 'w', encoding='utf-8') as f:
                f.write(translated_html)
            
            print(f"   ✅ 완료! ({translated_count}개 요소 번역됨)")
            
            # API 제한 방지를 위한 딜레이
            time.sleep(1)
            
        except Exception as e:
            print(f"   ❌ 오류 발생: {filename} - {e}")
    
    print("\n🎉 모든 파일 완전 번역 완료!")

def main():
    """
    사용자가 폴더 경로를 입력하여 완전 번역을 실행하는 함수
    """
    print("=== HTML 폴더 완전 번역 프로그램 ===\n")
    print("📋 번역 대상:")
    print("  • HTML 텍스트 콘텐츠")
    print("  • 메타 태그 (description, keywords, og:title 등)")
    print("  • JSON-LD 구조화된 데이터")
    print("  • JavaScript 주석 및 문자열")
    print("  • 속성값 (alt, title, placeholder 등)")
    print()
    
    input_folder = input("번역할 HTML 파일들이 있는 폴더 경로를 입력하세요: ").strip()
    output_folder = input("번역된 파일들을 저장할 폴더 경로를 입력하세요: ").strip()
    
    if not os.path.exists(input_folder):
        print(f"❌ 입력 폴더가 존재하지 않습니다: {input_folder}")
        return
    
    translate_html_complete(input_folder, output_folder)

if __name__ == "__main__":
    main()
# Out:
# === HTML 폴더 완전 번역 프로그램 ===
#
# 📋 번역 대상:
#   • HTML 텍스트 콘텐츠
#   • 메타 태그 (description, keywords, og:title 등)
#   • JSON-LD 구조화된 데이터
#   • JavaScript 주석 및 문자열
#   • 속성값 (alt, title, placeholder 등)
# 번역할 HTML 파일들이 있는 폴더 경로를 입력하세요:  C:\Users\User\Documents\GitHub\emfls.github.io\report\travel
# 번역된 파일들을 저장할 폴더 경로를 입력하세요:  C:\Users\User\Downloads\perplexity_results
# 총 5385개의 HTML 파일을 발견했습니다.
# ⏭️  albania-berat.html - 이미 번역되어 건너뜀
# ⏭️  albania-durres.html - 이미 번역되어 건너뜀
# ⏭️  albania-elbasan.html - 이미 번역되어 건너뜀
# ⏭️  albania-fier.html - 이미 번역되어 건너뜀
# ⏭️  albania-gjirokaster.html - 이미 번역되어 건너뜀
# ⏭️  albania-kavaje.html - 이미 번역되어 건너뜀
# ⏭️  albania-korce.html - 이미 번역되어 건너뜀
# ⏭️  albania-kruje.html - 이미 번역되어 건너뜀
# ⏭️  albania-kucove.html - 이미 번역되어 건너뜀
# ⏭️  albania-kukes.html - 이미 번역되어 건너뜀
# ⏭️  albania-lac.html - 이미 번역되어 건너뜀
# ⏭️  albania-lezhe.html - 이미 번역되어 건너뜀
# ⏭️  albania-lushnje.html - 이미 번역되어 건너뜀
# ⏭️  albania-patos.html - 이미 번역되어 건너뜀
# ⏭️  albania-peshkopi.html - 이미 번역되어 건너뜀
# ⏭️  albania-pogradec.html - 이미 번역되어 건너뜀
# ⏭️  albania-saranda.html - 이미 번역되어 건너뜀
# ⏭️  albania-shkoder.html - 이미 번역되어 건너뜀
# ⏭️  albania-tirana.html - 이미 번역되어 건너뜀
# ⏭️  albania-vlore.html - 이미 번역되어 건너뜀
# ⏭️  algeria-adrar.html - 이미 번역되어 건너뜀
# ⏭️  algeria-ain-temouchent.html - 이미 번역되어 건너뜀
# ⏭️  algeria-aindefla.html - 이미 번역되어 건너뜀
# ⏭️  algeria-algiers.html - 이미 번역되어 건너뜀
# ⏭️  algeria-annaba.html - 이미 번역되어 건너뜀
# ⏭️  algeria-batna.html - 이미 번역되어 건너뜀
# ⏭️  algeria-bechar.html - 이미 번역되어 건너뜀
# ⏭️  algeria-bejaia.html - 이미 번역되어 건너뜀
# ⏭️  algeria-biskra.html - 이미 번역되어 건너뜀
# ⏭️  algeria-blida.html - 이미 번역되어 건너뜀
# ⏭️  algeria-bordj-bou-arreridj.html - 이미 번역되어 건너뜀
# ⏭️  algeria-bouira.html - 이미 번역되어 건너뜀
# ⏭️  algeria-boumerdes.html - 이미 번역되어 건너뜀
# ⏭️  algeria-constantine.html - 이미 번역되어 건너뜀
# ⏭️  algeria-el-oued.html - 이미 번역되어 건너뜀
# ⏭️  algeria-elbayadh.html - 이미 번역되어 건너뜀
# ⏭️  algeria-elkef.html - 이미 번역되어 건너뜀
# ⏭️  algeria-eloued.html - 이미 번역되어 건너뜀
# ⏭️  algeria-eltarf.html - 이미 번역되어 건너뜀
# ⏭️  algeria-ghardaia.html - 이미 번역되어 건너뜀
# ⏭️  algeria-illizi.html - 이미 번역되어 건너뜀
# ⏭️  algeria-jijel.html - 이미 번역되어 건너뜀
# ⏭️  algeria-laghouat.html - 이미 번역되어 건너뜀
# ⏭️  algeria-medea.html - 이미 번역되어 건너뜀
# ⏭️  algeria-mostaganem.html - 이미 번역되어 건너뜀
# ⏭️  algeria-msila.html - 이미 번역되어 건너뜀
# ⏭️  algeria-naama.html - 이미 번역되어 건너뜀
# ⏭️  algeria-oran.html - 이미 번역되어 건너뜀
# ⏭️  algeria-ouargla.html - 이미 번역되어 건너뜀
# ⏭️  algeria-relizane.html - 이미 번역되어 건너뜀
# ⏭️  algeria-saida.html - 이미 번역되어 건너뜀
# ⏭️  algeria-setif.html - 이미 번역되어 건너뜀
# ⏭️  algeria-sidi-bel-abbes.html - 이미 번역되어 건너뜀
# ⏭️  algeria-skikda.html - 이미 번역되어 건너뜀
# ⏭️  algeria-soukaras.html - 이미 번역되어 건너뜀
# ⏭️  algeria-tamanrasset.html - 이미 번역되어 건너뜀
# ⏭️  algeria-tiaret.html - 이미 번역되어 건너뜀
# ⏭️  algeria-tipaza.html - 이미 번역되어 건너뜀
# ⏭️  algeria-tissemsilt.html - 이미 번역되어 건너뜀
# ⏭️  algeria-tlemcen.html - 이미 번역되어 건너뜀
# ⏭️  andorra-canillo.html - 이미 번역되어 건너뜀
# ⏭️  andorra-encamp.html - 이미 번역되어 건너뜀
# ⏭️  andorra-escaldes-engordany.html - 이미 번역되어 건너뜀
# ⏭️  andorra-lamassana.html - 이미 번역되어 건너뜀
# ⏭️  andorra-lavella.html - 이미 번역되어 건너뜀
# ⏭️  andorra-ordino.html - 이미 번역되어 건너뜀
# ⏭️  andorra-sant-julia-de-loria.html - 이미 번역되어 건너뜀
# 🔄 번역 중... (68/5385): angola-benguela.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
# C:\Users\User\AppData\Local\Temp\ipykernel_4024\3475159143.py:169: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   text_nodes = soup.find_all(text=True)
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (182개 요소 번역됨)
# 🔄 번역 중... (69/5385): angola-bie.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (70/5385): angola-cabinda.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (203개 요소 번역됨)
# 🔄 번역 중... (71/5385): angola-cacuso.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (174개 요소 번역됨)
# 🔄 번역 중... (72/5385): angola-calundo.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (176개 요소 번역됨)
# 🔄 번역 중... (73/5385): angola-camabatela.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (176개 요소 번역됨)
# 🔄 번역 중... (74/5385): angola-camacupa.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (182개 요소 번역됨)
# 🔄 번역 중... (75/5385): angola-carulo.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (174개 요소 번역됨)
# 🔄 번역 중... (76/5385): angola-catapua.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (187개 요소 번역됨)
# 🔄 번역 중... (77/5385): angola-cuando-cubango.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (198개 요소 번역됨)
# 🔄 번역 중... (78/5385): angola-cuanza-norte.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (187개 요소 번역됨)
# 🔄 번역 중... (79/5385): angola-cuanzasul.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (178개 요소 번역됨)
# 🔄 번역 중... (80/5385): angola-cubal.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (185개 요소 번역됨)
# 🔄 번역 중... (81/5385): angola-cunene.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (204개 요소 번역됨)
# 🔄 번역 중... (82/5385): angola-huambo.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (199개 요소 번역됨)
# 🔄 번역 중... (83/5385): angola-huila.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (196개 요소 번역됨)
# 🔄 번역 중... (84/5385): angola-lobito.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (205개 요소 번역됨)
# 🔄 번역 중... (85/5385): angola-luanda.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (188개 요소 번역됨)
# 🔄 번역 중... (86/5385): angola-lucapa.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (183개 요소 번역됨)
# 🔄 번역 중... (87/5385): angola-lunda-norte.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (184개 요소 번역됨)
# 🔄 번역 중... (88/5385): angola-lundasul.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (186개 요소 번역됨)
# 🔄 번역 중... (89/5385): angola-malanje.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (182개 요소 번역됨)
# 🔄 번역 중... (90/5385): angola-menongue.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (188개 요소 번역됨)
# 🔄 번역 중... (91/5385): angola-mocamedes.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (181개 요소 번역됨)
# 🔄 번역 중... (92/5385): angola-moxico.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (176개 요소 번역됨)
# 🔄 번역 중... (93/5385): angola-namibe.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (184개 요소 번역됨)
# 🔄 번역 중... (94/5385): angola-soyo.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (191개 요소 번역됨)
# 🔄 번역 중... (95/5385): angola-uige.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (96/5385): angola-zaire.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (201개 요소 번역됨)
# 🔄 번역 중... (97/5385): antigua-barbuda-parham.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (98/5385): antigua-bolans.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (99/5385): antigua-freetown.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (100/5385): antigua-liberta.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (177개 요소 번역됨)
# 🔄 번역 중... (101/5385): antigua-old-road.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (102/5385): antigua-stjohns.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (179개 요소 번역됨)
# 🔄 번역 중... (103/5385): antigua-willikes.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (104/5385): argentina-bariloche.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (203개 요소 번역됨)
# 🔄 번역 중... (105/5385): argentina-buenosaires.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (187개 요소 번역됨)
# 🔄 번역 중... (106/5385): argentina-catamarca.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (107/5385): argentina-cordoba.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (183개 요소 번역됨)
# 🔄 번역 중... (108/5385): argentina-jujuy.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (217개 요소 번역됨)
# 🔄 번역 중... (109/5385): argentina-laplata.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (173개 요소 번역됨)
# 🔄 번역 중... (110/5385): argentina-larioja.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (181개 요소 번역됨)
# 🔄 번역 중... (111/5385): argentina-mardelplata.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (112/5385): argentina-mendoza.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (181개 요소 번역됨)
# 🔄 번역 중... (113/5385): argentina-neuquen.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (186개 요소 번역됨)
# 🔄 번역 중... (114/5385): argentina-resistencia.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (173개 요소 번역됨)
# 🔄 번역 중... (115/5385): argentina-riogallegos.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (173개 요소 번역됨)
# 🔄 번역 중... (116/5385): argentina-rosario.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (167개 요소 번역됨)
# 🔄 번역 중... (117/5385): argentina-salta.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (182개 요소 번역됨)
# 🔄 번역 중... (118/5385): argentina-san-luis.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (173개 요소 번역됨)
# 🔄 번역 중... (119/5385): argentina-sanjuan.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (180개 요소 번역됨)
# 🔄 번역 중... (120/5385): argentina-santafe.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (178개 요소 번역됨)
# 🔄 번역 중... (121/5385): argentina-santarosa.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (173개 요소 번역됨)
# 🔄 번역 중... (122/5385): argentina-santiago-del-estero.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (205개 요소 번역됨)
# 🔄 번역 중... (123/5385): argentina-tucuman.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (124/5385): argentina-ushuaia.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (170개 요소 번역됨)
# 🔄 번역 중... (125/5385): armenia-abovyan.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (173개 요소 번역됨)
# 🔄 번역 중... (126/5385): armenia-alaverdi.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (127/5385): armenia-ararat.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (128/5385): armenia-armavir.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (182개 요소 번역됨)
# 🔄 번역 중... (129/5385): armenia-artashat.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (130/5385): armenia-ashtarak.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (131/5385): armenia-dilijan.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (132/5385): armenia-gavar.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (133/5385): armenia-goris.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (174개 요소 번역됨)
# 🔄 번역 중... (134/5385): armenia-gyumri.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (135/5385): armenia-hrazdan.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (136/5385): armenia-ijevan.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (173개 요소 번역됨)
# 🔄 번역 중... (137/5385): armenia-kapan.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (138/5385): armenia-khachavan.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (139/5385): armenia-martuni.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (180개 요소 번역됨)
# 🔄 번역 중... (140/5385): armenia-masis.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (174개 요소 번역됨)
# 🔄 번역 중... (141/5385): armenia-sevan.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (142/5385): armenia-spitak.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (143/5385): armenia-stepanavan.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (144/5385): armenia-vagharshapat.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (181개 요소 번역됨)
# 🔄 번역 중... (145/5385): armenia-vanadzor.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (173개 요소 번역됨)
# 🔄 번역 중... (146/5385): armenia-vardenis.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (174개 요소 번역됨)
# 🔄 번역 중... (147/5385): armenia-vedi.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (173개 요소 번역됨)
# 🔄 번역 중... (148/5385): armenia-yeghvard.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (149/5385): armenia-yerevan.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (173개 요소 번역됨)
# 🔄 번역 중... (150/5385): australia-adelaide.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (166개 요소 번역됨)
# 🔄 번역 중... (151/5385): australia-albury.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (163개 요소 번역됨)
# 🔄 번역 중... (152/5385): australia-alicesprings.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (160개 요소 번역됨)
# 🔄 번역 중... (153/5385): australia-ballarat.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (169개 요소 번역됨)
# 🔄 번역 중... (154/5385): australia-bendigo.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (166개 요소 번역됨)
# 🔄 번역 중... (155/5385): australia-brisbane.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (157개 요소 번역됨)
# 🔄 번역 중... (156/5385): australia-broome.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (159개 요소 번역됨)
# 🔄 번역 중... (157/5385): australia-bundaberg.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (154개 요소 번역됨)
# 🔄 번역 중... (158/5385): australia-cairns.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (149개 요소 번역됨)
# 🔄 번역 중... (159/5385): australia-canberra.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (165개 요소 번역됨)
# 🔄 번역 중... (160/5385): australia-darwin.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (160개 요소 번역됨)
# 🔄 번역 중... (161/5385): australia-geelong.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (169개 요소 번역됨)
# 🔄 번역 중... (162/5385): australia-gladstone.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (165개 요소 번역됨)
# 🔄 번역 중... (163/5385): australia-goldcoast.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (158개 요소 번역됨)
# 🔄 번역 중... (164/5385): australia-hervey-bay.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (180개 요소 번역됨)
# 🔄 번역 중... (165/5385): australia-hobart.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (185개 요소 번역됨)
# 🔄 번역 중... (166/5385): australia-kalgoorlie.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (167/5385): australia-launceston.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (165개 요소 번역됨)
# 🔄 번역 중... (168/5385): australia-mackay.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (169/5385): australia-melbourne.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (162개 요소 번역됨)
# 🔄 번역 중... (170/5385): australia-newcastle.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (160개 요소 번역됨)
# 🔄 번역 중... (171/5385): australia-perth.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (143개 요소 번역됨)
# 🔄 번역 중... (172/5385): australia-portmacquarie.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (167개 요소 번역됨)
# 🔄 번역 중... (173/5385): australia-rockhampton.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (163개 요소 번역됨)
# 🔄 번역 중... (174/5385): australia-sunshinecoast.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (161개 요소 번역됨)
# 🔄 번역 중... (175/5385): australia-sydney.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (173개 요소 번역됨)
# 🔄 번역 중... (176/5385): australia-toowoomba.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (169개 요소 번역됨)
# 🔄 번역 중... (177/5385): australia-townsville.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (165개 요소 번역됨)
# 🔄 번역 중... (178/5385): australia-wagga.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (163개 요소 번역됨)
# 🔄 번역 중... (179/5385): australia-wollongong.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (180/5385): austria-amstetten.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (170개 요소 번역됨)
# 🔄 번역 중... (181/5385): austria-ansfelden.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (182/5385): austria-bad-voeslau.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (183/5385): austria-baden.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (184/5385): austria-badischl.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (185/5385): austria-bischofshofen.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (186/5385): austria-bludenz.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (187/5385): austria-braunau.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (188/5385): austria-bregenz.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (189/5385): austria-bruck.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# ...
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2890/5385): lithuania-vievis.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2891/5385): lithuania-vilnius.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2892/5385): lithuania-visaginas.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2893/5385): lithuania-zarasai.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2894/5385): luxembourg-bergem.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2895/5385): luxembourg-bertrange.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2896/5385): luxembourg-bettembourg.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    💬 주석 건너뜀: 자...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2897/5385): luxembourg-capellen.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2898/5385): luxembourg-clervaux.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2899/5385): luxembourg-contern.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2900/5385): luxembourg-diekirch.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2901/5385): luxembourg-dudelange.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2902/5385): luxembourg-echternach.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2903/5385): luxembourg-esch.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2904/5385): luxembourg-grevenmacher.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2905/5385): luxembourg-luxembourg.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2906/5385): luxembourg-mersch.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2907/5385): luxembourg-mondorf.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2908/5385): luxembourg-nommern.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (157개 요소 번역됨)
# 🔄 번역 중... (2909/5385): luxembourg-petange.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2910/5385): luxembourg-redingen.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2911/5385): luxembourg-remingen.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2912/5385): luxembourg-rempert.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2913/5385): luxembourg-sandweiler.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2914/5385): luxembourg-steinfort.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (171개 요소 번역됨)
# 🔄 번역 중... (2915/5385): luxembourg-strassen.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
#    📄 DOCTYPE 보존: <!doctype html>
#    ✅ 완료! (172개 요소 번역됨)
# 🔄 번역 중... (2916/5385): luxembourg-wasserbillig.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    💬 주석 건너뜀: Open Graph Meta Tags...
#    💬 주석 건너뜀: Canonical URL...
#    💬 주석 건너뜀: Google 태그 (gtag.js)...
#    💬 주석 건너뜀: Structured Data...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 248
#     245     translate_html_complete(input_folder, output_folder)
#     247 if __name__ == "__main__":
# --> 248     main()
#
# Cell In[7], line 245, in main()
#     242     print(f"❌ 입력 폴더가 존재하지 않습니다: {input_folder}")
#     243     return
# --> 245 translate_html_complete(input_folder, output_folder)
#
# Cell In[7], line 180, in translate_html_complete(input_folder, output_folder, source_lang, target_lang)
#     175 if (text.strip() and
#     176     text.parent.name not in ['script', 'style', 'meta'] and
#     177     not isinstance(text, Comment) and
#     178     not is_english_text(text.strip())):
#     179     try:
# --> 180         translated = translator.translate(text.strip())
#     181         text.replace_with(translated)
#     182         translated_count += 1
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\deep_translator\google.py:67, in GoogleTranslator.translate(self, text, **kwargs)
#      64 if self.payload_key:
#      65     self._url_params[self.payload_key] = text
# ---> 67 response = requests.get(
#      68     self._base_url, params=self._url_params, proxies=self.proxies
#      69 )
#      70 if response.status_code == 429:
#      71     raise TooManyRequests()
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\response.py:624, in HTTPResponse.stream(self, amt, decode_content)
#     608 """
#     609 A generator wrapper for the read() method. A call will block until
#     610 ``amt`` bytes have been read from the connection or until the
#    (...)
#     621     'content-encoding' header.
#     622 """
#     623 if self.chunked and self.supports_chunked_reads():
# --> 624     for line in self.read_chunked(amt, decode_content=decode_content):
#     625         yield line
#     626 else:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\response.py:828, in HTTPResponse.read_chunked(self, amt, decode_content)
#     825     return
#     827 while True:
# --> 828     self._update_chunk_length()
#     829     if self.chunk_left == 0:
#     830         break
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\response.py:758, in HTTPResponse._update_chunk_length(self)
#     756 if self.chunk_left is not None:
#     757     return
# --> 758 line = self._fp.fp.readline()
#     759 line = line.split(b";", 1)[0]
#     760 try:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import os
import glob
from deep_translator import GoogleTranslator
from bs4 import BeautifulSoup, Comment
import time
import re
import json
import concurrent.futures
import threading

def clean_html_formatting(html_str):
    """
    HTML 포맷팅 정리 함수
    - DOCTYPE 하단 불필요한 'html' 텍스트 제거
    """
    doctype_match = re.search(r'<!DOCTYPE[^>]*>', html_str, re.IGNORECASE)
    doctype = doctype_match.group(0) if doctype_match else ''
    after_doctype = html_str[doctype_match.end():] if doctype_match else html_str
    after_doctype = re.sub(r'^\s*html\s*\n', '', after_doctype, flags=re.IGNORECASE)
    if doctype:
        cleaned_html = doctype + '\n' + after_doctype.lstrip()
    else:
        cleaned_html = after_doctype
    return cleaned_html

def translate_json_content(json_str, translator):
    """
    JSON 구조화된 데이터 내 텍스트 번역
    """
    try:
        data = json.loads(json_str)
        
        def translate_recursive(obj):
            if isinstance(obj, dict):
                for key, value in obj.items():
                    if isinstance(value, str) and value.strip():
                        # 영어가 아닌 텍스트만 번역
                        if not is_english_text(value):
                            try:
                                obj[key] = translator.translate(value)
                            except:
                                pass
                    elif isinstance(value, (dict, list)):
                        translate_recursive(value)
            elif isinstance(obj, list):
                for i, item in enumerate(obj):
                    if isinstance(item, str) and item.strip():
                        if not is_english_text(item):
                            try:
                                obj[i] = translator.translate(item)
                            except:
                                pass
                    elif isinstance(item, (dict, list)):
                        translate_recursive(item)
        
        translate_recursive(data)
        return json.dumps(data, ensure_ascii=False, indent=16)
    except:
        return json_str

def is_english_text(text):
    """
    텍스트가 영어인지 간단히 판단
    """
    if not text.strip():
        return True
    
    # URL, 이메일, 특수 코드는 번역하지 않음
    if any(pattern in text.lower() for pattern in ['http', 'www.', '@', '.com', '.html', 'gtag', 'dataLayer']):
        return True
    
    # 숫자만 있는 경우
    if text.strip().replace(' ', '').replace('-', '').replace('/', '').isdigit():
        return True
    
    # 한글이 포함된 경우 한국어로 판단
    if any('\uac00' <= char <= '\ud7af' for char in text):
        return False
    
    return True

def translate_single_html_file(html_file, output_folder, request_lock, last_request_time, delay_between_requests=2):
    """
    단일 HTML 파일을 번역하는 함수 (병렬 처리용)
    """
    filename = os.path.basename(html_file)
    output_file = os.path.join(output_folder, filename)
    
    if os.path.exists(output_file):
        print(f"⏭️  {filename} - 이미 번역되어 건너뜀")
        return
    
    # API 요청 간격 조절
    with request_lock:
        current_time = time.time()
        time_since_last = current_time - last_request_time[0]
        if time_since_last < delay_between_requests:
            time.sleep(delay_between_requests - time_since_last)
        last_request_time[0] = time.time()
    
    print(f"🔄 번역 중... {filename}")
    
    try:
        # 각 스레드마다 별도의 translator 인스턴스 생성
        translator = GoogleTranslator(source='auto', target=language_)
        
        with open(html_file, 'r', encoding='utf-8') as f:
            original_content = f.read()
        
        # DOCTYPE 선언 추출 및 보존
        doctype_match = re.search(r'<!DOCTYPE[^>]*>', original_content, re.IGNORECASE)
        original_doctype = doctype_match.group(0) if doctype_match else None
        
        # BeautifulSoup으로 파싱
        soup = BeautifulSoup(original_content, 'html.parser')
        
        translated_count = 0
        
        # 1. 메타 태그 번역
        meta_tags = soup.find_all('meta')
        for meta in meta_tags:
            if meta.get('content') and not is_english_text(meta.get('content')):
                try:
                    translated_content = translator.translate(meta.get('content'))
                    meta['content'] = translated_content
                    translated_count += 1
                    print(f"   🏷️  메타태그 번역: {meta.get('name') or meta.get('property')}")
                except:
                    pass
        
        # 2. JSON-LD 구조화된 데이터 번역
        json_scripts = soup.find_all('script', type='application/ld+json')
        for script in json_scripts:
            if script.string:
                translated_json = translate_json_content(script.string, translator)
                script.string = translated_json
                print(f"   📊 JSON-LD 데이터 번역 완료")
        
        # 3. JavaScript 주석 및 문자열 번역
        js_scripts = soup.find_all('script', type=lambda x: x != 'application/ld+json')
        for script in js_scripts:
            if script.string:
                js_content = script.string
                # JavaScript 주석 내 한국어 번역
                comment_pattern = r'//\s*(.+)'
                matches = re.findall(comment_pattern, js_content)
                for match in matches:
                    if not is_english_text(match):
                        try:
                            translated_comment = translator.translate(match)
                            js_content = js_content.replace(match, translated_comment)
                            translated_count += 1
                        except:
                            pass
                
                # JavaScript 문자열 내 한국어 번역
                string_pattern = r'"([^"]*[가-힣]+[^"]*)"'
                matches = re.findall(string_pattern, js_content)
                for match in matches:
                    if not is_english_text(match):
                        try:
                            translated_string = translator.translate(match)
                            js_content = js_content.replace(f'"{match}"', f'"{translated_string}"')
                            translated_count += 1
                        except:
                            pass
                
                script.string = js_content
        
        # 4. 일반 텍스트 노드 번역
        text_nodes = soup.find_all(text=True)
        for text in text_nodes:
            if isinstance(text, Comment):
                continue
            
            if (text.strip() and 
                text.parent.name not in ['script', 'style', 'meta'] and
                not isinstance(text, Comment) and
                not is_english_text(text.strip())):
                try:
                    translated = translator.translate(text.strip())
                    text.replace_with(translated)
                    translated_count += 1
                except Exception as e:
                    print(f"   ⚠️  텍스트 번역 실패: {text.strip()[:30]}... - {e}")
                    continue
        
        # 5. 속성값 번역 (alt, title, placeholder 등)
        for tag in soup.find_all():
            for attr in ['alt', 'title', 'placeholder', 'aria-label']:
                if tag.get(attr) and not is_english_text(tag.get(attr)):
                    try:
                        translated_attr = translator.translate(tag.get(attr))
                        tag[attr] = translated_attr
                        translated_count += 1
                        print(f"   🔖 속성 번역: {attr}")
                    except:
                        pass
        
        # HTML 문자열로 변환
        translated_html = str(soup)
        
        # 원본 DOCTYPE 복원
        if original_doctype:
            translated_html = re.sub(r'<!DOCTYPE[^>]*>\s*', '', translated_html, flags=re.IGNORECASE)
            translated_html = original_doctype + '\n' + translated_html
        
        # HTML 포맷팅 정리
        translated_html = clean_html_formatting(translated_html)
        
        # 번역된 파일 저장
        with open(output_file, 'w', encoding='utf-8') as f:
            f.write(translated_html)
        
        print(f"   ✅ 완료! {filename} ({translated_count}개 요소 번역됨)")
        
    except Exception as e:
        print(f"   ❌ 오류 발생: {filename} - {e}")

def translate_html_parallel(input_folder, output_folder, max_workers=3, delay_between_requests=2, source_lang='auto', target_lang=language_):
    """
    병렬 처리로 HTML 파일들을 번역하는 함수
    """
    os.makedirs(output_folder, exist_ok=True)
    html_files = glob.glob(os.path.join(input_folder, '*.html'))
    
    if not html_files:
        print(f"'{input_folder}' 폴더에 HTML 파일이 없습니다.")
        return
    
    print(f"총 {len(html_files)}개의 HTML 파일을 {max_workers}개 스레드로 처리합니다.")
    print(f"API 요청 간격: {delay_between_requests}초")
    print()
    
    # 스레드 간 요청 간격 조절을 위한 락
    request_lock = threading.Lock()
    last_request_time = [0]  # 리스트로 감싸서 참조 가능하게 함
    
    # ThreadPoolExecutor로 병렬 처리
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        futures = [
            executor.submit(
                translate_single_html_file, 
                html_file, 
                output_folder, 
                request_lock, 
                last_request_time, 
                delay_between_requests
            ) 
            for html_file in html_files
        ]
        
        # 모든 작업 완료 대기
        completed = 0
        for future in concurrent.futures.as_completed(futures):
            try:
                future.result()
                completed += 1
                print(f"📊 진행률: {completed}/{len(html_files)} 완료")
            except Exception as e:
                print(f"스레드 실행 중 오류: {e}")
    
    print("\n🎉 모든 파일 병렬 번역 완료!")

def translate_html_complete(input_folder, output_folder, source_lang='auto', target_lang=language_):
    """
    HTML 파일들을 순차적으로 번역하는 함수 (기존 방식)
    """
    os.makedirs(output_folder, exist_ok=True)
    translator = GoogleTranslator(source=source_lang, target=target_lang)
    html_files = glob.glob(os.path.join(input_folder, '*.html'))
    
    if not html_files:
        print(f"'{input_folder}' 폴더에 HTML 파일이 없습니다.")
        return
    
    print(f"총 {len(html_files)}개의 HTML 파일을 발견했습니다.")
    
    for i, html_file in enumerate(html_files):
        filename = os.path.basename(html_file)
        output_file = os.path.join(output_folder, filename)
        
        if os.path.exists(output_file):
            print(f"⏭️  {filename} - 이미 번역되어 건너뜀")
            continue
        
        print(f"🔄 번역 중... ({i+1}/{len(html_files)}): {filename}")
        
        try:
            with open(html_file, 'r', encoding='utf-8') as f:
                original_content = f.read()
            
            # DOCTYPE 선언 추출 및 보존
            doctype_match = re.search(r'<!DOCTYPE[^>]*>', original_content, re.IGNORECASE)
            original_doctype = doctype_match.group(0) if doctype_match else None
            
            # BeautifulSoup으로 파싱
            soup = BeautifulSoup(original_content, 'html.parser')
            
            translated_count = 0
            
            # 1. 메타 태그 번역
            meta_tags = soup.find_all('meta')
            for meta in meta_tags:
                if meta.get('content') and not is_english_text(meta.get('content')):
                    try:
                        translated_content = translator.translate(meta.get('content'))
                        meta['content'] = translated_content
                        translated_count += 1
                        print(f"   🏷️  메타태그 번역: {meta.get('name') or meta.get('property')}")
                    except:
                        pass
            
            # 2. JSON-LD 구조화된 데이터 번역
            json_scripts = soup.find_all('script', type='application/ld+json')
            for script in json_scripts:
                if script.string:
                    translated_json = translate_json_content(script.string, translator)
                    script.string = translated_json
                    print(f"   📊 JSON-LD 데이터 번역 완료")
            
            # 3. JavaScript 주석 및 문자열 번역
            js_scripts = soup.find_all('script', type=lambda x: x != 'application/ld+json')
            for script in js_scripts:
                if script.string:
                    js_content = script.string
                    # JavaScript 주석 내 한국어 번역
                    comment_pattern = r'//\s*(.+)'
                    matches = re.findall(comment_pattern, js_content)
                    for match in matches:
                        if not is_english_text(match):
                            try:
                                translated_comment = translator.translate(match)
                                js_content = js_content.replace(match, translated_comment)
                                translated_count += 1
                            except:
                                pass
                    
                    # JavaScript 문자열 내 한국어 번역
                    string_pattern = r'"([^"]*[가-힣]+[^"]*)"'
                    matches = re.findall(string_pattern, js_content)
                    for match in matches:
                        if not is_english_text(match):
                            try:
                                translated_string = translator.translate(match)
                                js_content = js_content.replace(f'"{match}"', f'"{translated_string}"')
                                translated_count += 1
                            except:
                                pass
                    
                    script.string = js_content
            
            # 4. 일반 텍스트 노드 번역
            text_nodes = soup.find_all(text=True)
            for text in text_nodes:
                if isinstance(text, Comment):
                    print(f"   💬 주석 건너뜀: {str(text).strip()[:30]}...")
                    continue
                
                if (text.strip() and 
                    text.parent.name not in ['script', 'style', 'meta'] and
                    not isinstance(text, Comment) and
                    not is_english_text(text.strip())):
                    try:
                        translated = translator.translate(text.strip())
                        text.replace_with(translated)
                        translated_count += 1
                    except Exception as e:
                        print(f"   ⚠️  텍스트 번역 실패: {text.strip()[:30]}... - {e}")
                        continue
            
            # 5. 속성값 번역 (alt, title, placeholder 등)
            for tag in soup.find_all():
                for attr in ['alt', 'title', 'placeholder', 'aria-label']:
                    if tag.get(attr) and not is_english_text(tag.get(attr)):
                        try:
                            translated_attr = translator.translate(tag.get(attr))
                            tag[attr] = translated_attr
                            translated_count += 1
                            print(f"   🔖 속성 번역: {attr}")
                        except:
                            pass
            
            # HTML 문자열로 변환
            translated_html = str(soup)
            
            # 원본 DOCTYPE 복원
            if original_doctype:
                translated_html = re.sub(r'<!DOCTYPE[^>]*>\s*', '', translated_html, flags=re.IGNORECASE)
                translated_html = original_doctype + '\n' + translated_html
                print(f"   📄 DOCTYPE 보존: {original_doctype}")
            
            # HTML 포맷팅 정리
            translated_html = clean_html_formatting(translated_html)
            
            # 번역된 파일 저장
            with open(output_file, 'w', encoding='utf-8') as f:
                f.write(translated_html)
            
            print(f"   ✅ 완료! ({translated_count}개 요소 번역됨)")
            
            # API 제한 방지를 위한 딜레이
            time.sleep(1)
            
        except Exception as e:
            print(f"   ❌ 오류 발생: {filename} - {e}")
    
    print("\n🎉 모든 파일 완전 번역 완료!")

def main():
    """
    사용자가 폴더 경로를 입력하여 완전 번역을 실행하는 함수
    """
    print("=== HTML 폴더 완전 번역 프로그램 ===\n")
    print("📋 번역 대상:")
    print("  • HTML 텍스트 콘텐츠")
    print("  • 메타 태그 (description, keywords, og:title 등)")
    print("  • JSON-LD 구조화된 데이터")
    print("  • JavaScript 주석 및 문자열")
    print("  • 속성값 (alt, title, placeholder 등)")
    print()
    
    input_folder = input("번역할 HTML 파일들이 있는 폴더 경로를 입력하세요: ").strip()
    output_folder = input("번역된 파일들을 저장할 폴더 경로를 입력하세요: ").strip()
    
    if not os.path.exists(input_folder):
        print(f"❌ 입력 폴더가 존재하지 않습니다: {input_folder}")
        return
    
    # 처리 방식 선택
    print("\n처리 방식을 선택하세요:")
    print("1. 순차 처리 (안전하지만 느림)")
    print("2. 병렬 처리 (빠르지만 API 제한 주의)")
    
    choice = input("선택 (1 또는 2): ").strip()
    
    if choice == "2":
        max_workers = 3
        delay = 3
        translate_html_parallel(input_folder, output_folder, max_workers=max_workers, delay_between_requests=delay)
    else:
        translate_html_complete(input_folder, output_folder)

if __name__ == "__main__":
    main()
# Out:
# === HTML 폴더 완전 번역 프로그램 ===
#
# 📋 번역 대상:
#   • HTML 텍스트 콘텐츠
#   • 메타 태그 (description, keywords, og:title 등)
#   • JSON-LD 구조화된 데이터
#   • JavaScript 주석 및 문자열
#   • 속성값 (alt, title, placeholder 등)
# 번역할 HTML 파일들이 있는 폴더 경로를 입력하세요:  C:\Users\User\Documents\GitHub\emfls.github.io\report\travel
# 번역된 파일들을 저장할 폴더 경로를 입력하세요:  C:\Users\User\Downloads\perplexity_results
# 처리 방식을 선택하세요:
# 1. 순차 처리 (안전하지만 느림)
# 2. 병렬 처리 (빠르지만 API 제한 주의)
# 선택 (1 또는 2):  2
# 동시 처리할 파일 수 (권장: 3-5):  3
# API 요청 간격 (초, 권장: 2-3):  3
# 총 5385개의 HTML 파일을 3개 스레드로 처리합니다.
# API 요청 간격: 3초
#
# ⏭️  albania-berat.html - 이미 번역되어 건너뜀
# ⏭️  albania-durres.html - 이미 번역되어 건너뜀
# ⏭️  albania-elbasan.html - 이미 번역되어 건너뜀
# ⏭️  albania-gjirokaster.html - 이미 번역되어 건너뜀
# ⏭️  albania-fier.html - 이미 번역되어 건너뜀
# ⏭️  albania-kavaje.html - 이미 번역되어 건너뜀
# ⏭️  albania-kucove.html - 이미 번역되어 건너뜀
# ⏭️  albania-korce.html - 이미 번역되어 건너뜀⏭️  albania-kruje.html - 이미 번역되어 건너뜀
#
# ⏭️  albania-kukes.html - 이미 번역되어 건너뜀
# ⏭️  albania-lezhe.html - 이미 번역되어 건너뜀
# ⏭️  albania-lac.html - 이미 번역되어 건너뜀
# ⏭️  albania-lushnje.html - 이미 번역되어 건너뜀
# ⏭️  albania-peshkopi.html - 이미 번역되어 건너뜀
# ⏭️  albania-pogradec.html - 이미 번역되어 건너뜀
# ⏭️  albania-saranda.html - 이미 번역되어 건너뜀
# ⏭️  albania-shkoder.html - 이미 번역되어 건너뜀
# ⏭️  albania-patos.html - 이미 번역되어 건너뜀
# ⏭️  albania-tirana.html - 이미 번역되어 건너뜀
# ⏭️  algeria-adrar.html - 이미 번역되어 건너뜀
# ⏭️  albania-vlore.html - 이미 번역되어 건너뜀
# ⏭️  algeria-ain-temouchent.html - 이미 번역되어 건너뜀
# ⏭️  algeria-aindefla.html - 이미 번역되어 건너뜀
# ⏭️  algeria-algiers.html - 이미 번역되어 건너뜀
# ⏭️  algeria-batna.html - 이미 번역되어 건너뜀
# ⏭️  algeria-bechar.html - 이미 번역되어 건너뜀
# ⏭️  algeria-bejaia.html - 이미 번역되어 건너뜀
# ⏭️  algeria-annaba.html - 이미 번역되어 건너뜀
# ⏭️  algeria-biskra.html - 이미 번역되어 건너뜀
# ⏭️  algeria-blida.html - 이미 번역되어 건너뜀
# ⏭️  algeria-bordj-bou-arreridj.html - 이미 번역되어 건너뜀
# ⏭️  algeria-constantine.html - 이미 번역되어 건너뜀
# ⏭️  algeria-bouira.html - 이미 번역되어 건너뜀
# ⏭️  algeria-boumerdes.html - 이미 번역되어 건너뜀
# ⏭️  algeria-el-oued.html - 이미 번역되어 건너뜀
# ⏭️  algeria-elbayadh.html - 이미 번역되어 건너뜀
# ⏭️  algeria-eloued.html - 이미 번역되어 건너뜀
# ⏭️  algeria-eltarf.html - 이미 번역되어 건너뜀
# ⏭️  algeria-ghardaia.html - 이미 번역되어 건너뜀
# ⏭️  algeria-elkef.html - 이미 번역되어 건너뜀
# ⏭️  algeria-jijel.html - 이미 번역되어 건너뜀
# ⏭️  algeria-illizi.html - 이미 번역되어 건너뜀
# ⏭️  algeria-medea.html - 이미 번역되어 건너뜀
# ⏭️  algeria-mostaganem.html - 이미 번역되어 건너뜀
# ⏭️  algeria-laghouat.html - 이미 번역되어 건너뜀
# ⏭️  algeria-naama.html - 이미 번역되어 건너뜀
# ⏭️  algeria-oran.html - 이미 번역되어 건너뜀
# ⏭️  algeria-msila.html - 이미 번역되어 건너뜀
# ⏭️  algeria-relizane.html - 이미 번역되어 건너뜀
# ⏭️  algeria-ouargla.html - 이미 번역되어 건너뜀
# ⏭️  algeria-setif.html - 이미 번역되어 건너뜀
# ⏭️  algeria-sidi-bel-abbes.html - 이미 번역되어 건너뜀
# ⏭️  algeria-saida.html - 이미 번역되어 건너뜀
# ⏭️  algeria-soukaras.html - 이미 번역되어 건너뜀
# ⏭️  algeria-tamanrasset.html - 이미 번역되어 건너뜀
# ⏭️  algeria-tipaza.html - 이미 번역되어 건너뜀
# ⏭️  algeria-tissemsilt.html - 이미 번역되어 건너뜀
# ⏭️  algeria-tlemcen.html - 이미 번역되어 건너뜀
# ⏭️  andorra-canillo.html - 이미 번역되어 건너뜀
# ⏭️  andorra-encamp.html - 이미 번역되어 건너뜀
# ⏭️  andorra-escaldes-engordany.html - 이미 번역되어 건너뜀
# ⏭️  andorra-lamassana.html - 이미 번역되어 건너뜀
# ⏭️  andorra-lavella.html - 이미 번역되어 건너뜀
# ⏭️  andorra-ordino.html - 이미 번역되어 건너뜀
# ⏭️  andorra-sant-julia-de-loria.html - 이미 번역되어 건너뜀
# ⏭️  algeria-skikda.html - 이미 번역되어 건너뜀
# ⏭️  algeria-tiaret.html - 이미 번역되어 건너뜀
# ⏭️  angola-benguela.html - 이미 번역되어 건너뜀
# 📊 진행률: 1/5385 완료
# 📊 진행률: 2/5385 완료
# 📊 진행률: 3/5385 완료
# 📊 진행률: 4/5385 완료
# 📊 진행률: 5/5385 완료
# 📊 진행률: 6/5385 완료
# 📊 진행률: 7/5385 완료
# 📊 진행률: 8/5385 완료
# 📊 진행률: 9/5385 완료
# 📊 진행률: 10/5385 완료
# 📊 진행률: 11/5385 완료
# 📊 진행률: 12/5385 완료
# 📊 진행률: 13/5385 완료
# 📊 진행률: 14/5385 완료
# 📊 진행률: 15/5385 완료
# 📊 진행률: 16/5385 완료
# 📊 진행률: 17/5385 완료
# 📊 진행률: 18/5385 완료
# 📊 진행률: 19/5385 완료
# 📊 진행률: 20/5385 완료
# 📊 진행률: 21/5385 완료
# 📊 진행률: 22/5385 완료
# 📊 진행률: 23/5385 완료
# 📊 진행률: 24/5385 완료
# 📊 진행률: 25/5385 완료
# 📊 진행률: 26/5385 완료
# 📊 진행률: 27/5385 완료
# 📊 진행률: 28/5385 완료
# 📊 진행률: 29/5385 완료
# 📊 진행률: 30/5385 완료
# 📊 진행률: 31/5385 완료
# 📊 진행률: 32/5385 완료
# 📊 진행률: 33/5385 완료
# 📊 진행률: 34/5385 완료
# 📊 진행률: 35/5385 완료
# 📊 진행률: 36/5385 완료
# 📊 진행률: 37/5385 완료
# 📊 진행률: 38/5385 완료
# 📊 진행률: 39/5385 완료
# 📊 진행률: 40/5385 완료
# 📊 진행률: 41/5385 완료
# 📊 진행률: 42/5385 완료
# 📊 진행률: 43/5385 완료
# 📊 진행률: 44/5385 완료
# 📊 진행률: 45/5385 완료
# 📊 진행률: 46/5385 완료
# 📊 진행률: 47/5385 완료
# 📊 진행률: 48/5385 완료
# 📊 진행률: 49/5385 완료
# 📊 진행률: 50/5385 완료
# 📊 진행률: 51/5385 완료
# 📊 진행률: 52/5385 완료
# 📊 진행률: 53/5385 완료
# 📊 진행률: 54/5385 완료
# 📊 진행률: 55/5385 완료
# 📊 진행률: 56/5385 완료
# 📊 진행률: 57/5385 완료
# 📊 진행률: 58/5385 완료
# 📊 진행률: 59/5385 완료
# 📊 진행률: 60/5385 완료
# 📊 진행률: 61/5385 완료
# 📊 진행률: 62/5385 완료
# 📊 진행률: 63/5385 완료
# 📊 진행률: 64/5385 완료
# 📊 진행률: 65/5385 완료
# 📊 진행률: 66/5385 완료
# ⏭️  angola-bie.html - 이미 번역되어 건너뜀
# ⏭️  angola-cabinda.html - 이미 번역되어 건너뜀
# 📊 진행률: 67/5385 완료
# 📊 진행률: 68/5385 완료
# 📊 진행률: 69/5385 완료
# ⏭️  angola-cacuso.html - 이미 번역되어 건너뜀
# ⏭️  angola-camabatela.html - 이미 번역되어 건너뜀
# ⏭️  angola-camacupa.html - 이미 번역되어 건너뜀
# ⏭️  angola-carulo.html - 이미 번역되어 건너뜀
# ⏭️  angola-catapua.html - 이미 번역되어 건너뜀
# ⏭️  angola-cuando-cubango.html - 이미 번역되어 건너뜀
# ⏭️  angola-cuanza-norte.html - 이미 번역되어 건너뜀
# ⏭️  angola-cuanzasul.html - 이미 번역되어 건너뜀
# ⏭️  angola-cubal.html - 이미 번역되어 건너뜀
# ⏭️  angola-cunene.html - 이미 번역되어 건너뜀
# ⏭️  angola-huambo.html - 이미 번역되어 건너뜀
# ⏭️  angola-huila.html - 이미 번역되어 건너뜀
# ⏭️  angola-lobito.html - 이미 번역되어 건너뜀
# 📊 진행률: 70/5385 완료
# 📊 진행률: 71/5385 완료
# 📊 진행률: 72/5385 완료
# 📊 진행률: 73/5385 완료
# 📊 진행률: 74/5385 완료
# 📊 진행률: 75/5385 완료
# 📊 진행률: 76/5385 완료
# 📊 진행률: 77/5385 완료
# 📊 진행률: 78/5385 완료
# 📊 진행률: 79/5385 완료
# 📊 진행률: 80/5385 완료
# 📊 진행률: 81/5385 완료
# 📊 진행률: 82/5385 완료
# ⏭️  angola-lucapa.html - 이미 번역되어 건너뜀
# ⏭️  angola-lunda-norte.html - 이미 번역되어 건너뜀
# ⏭️  angola-lundasul.html - 이미 번역되어 건너뜀
# ⏭️  angola-malanje.html - 이미 번역되어 건너뜀
# ⏭️  angola-menongue.html - 이미 번역되어 건너뜀
# ⏭️  angola-mocamedes.html - 이미 번역되어 건너뜀
# ⏭️  angola-moxico.html - 이미 번역되어 건너뜀
# ⏭️  angola-namibe.html - 이미 번역되어 건너뜀
# ⏭️  angola-soyo.html - 이미 번역되어 건너뜀
# ⏭️  angola-uige.html - 이미 번역되어 건너뜀
# ⏭️  angola-zaire.html - 이미 번역되어 건너뜀
# ⏭️  antigua-barbuda-parham.html - 이미 번역되어 건너뜀
# ⏭️  antigua-bolans.html - 이미 번역되어 건너뜀
# ⏭️  antigua-freetown.html - 이미 번역되어 건너뜀
# ⏭️  antigua-liberta.html - 이미 번역되어 건너뜀
# ⏭️  angola-calundo.html - 이미 번역되어 건너뜀
# ⏭️  antigua-stjohns.html - 이미 번역되어 건너뜀
# ⏭️  antigua-willikes.html - 이미 번역되어 건너뜀
# ⏭️  argentina-bariloche.html - 이미 번역되어 건너뜀
# ⏭️  argentina-buenosaires.html - 이미 번역되어 건너뜀
# ⏭️  argentina-catamarca.html - 이미 번역되어 건너뜀
# ⏭️  argentina-cordoba.html - 이미 번역되어 건너뜀
# 📊 진행률: 83/5385 완료
# 📊 진행률: 84/5385 완료
# 📊 진행률: 85/5385 완료
# 📊 진행률: 86/5385 완료
# 📊 진행률: 87/5385 완료
# 📊 진행률: 88/5385 완료
# 📊 진행률: 89/5385 완료
# 📊 진행률: 90/5385 완료
# 📊 진행률: 91/5385 완료
# 📊 진행률: 92/5385 완료
# 📊 진행률: 93/5385 완료
# 📊 진행률: 94/5385 완료
# 📊 진행률: 95/5385 완료
# 📊 진행률: 96/5385 완료
# 📊 진행률: 97/5385 완료
# 📊 진행률: 98/5385 완료
# 📊 진행률: 99/5385 완료
# 📊 진행률: 100/5385 완료
# 📊 진행률: 101/5385 완료
# 📊 진행률: 102/5385 완료
# 📊 진행률: 103/5385 완료
# 📊 진행률: 104/5385 완료
# 📊 진행률: 105/5385 완료
# ⏭️  angola-luanda.html - 이미 번역되어 건너뜀
# ⏭️  antigua-old-road.html - 이미 번역되어 건너뜀
# ⏭️  argentina-laplata.html - 이미 번역되어 건너뜀
# ⏭️  argentina-mardelplata.html - 이미 번역되어 건너뜀
# ⏭️  argentina-larioja.html - 이미 번역되어 건너뜀
# ⏭️  argentina-mendoza.html - 이미 번역되어 건너뜀
# ⏭️  argentina-neuquen.html - 이미 번역되어 건너뜀
# 📊 진행률: 106/5385 완료
# 📊 진행률: 107/5385 완료
# 📊 진행률: 108/5385 완료
# 📊 진행률: 109/5385 완료
# 📊 진행률: 110/5385 완료
# 📊 진행률: 111/5385 완료
# 📊 진행률: 112/5385 완료
# ⏭️  argentina-resistencia.html - 이미 번역되어 건너뜀
# ⏭️  argentina-riogallegos.html - 이미 번역되어 건너뜀
# ⏭️  argentina-rosario.html - 이미 번역되어 건너뜀
# ⏭️  argentina-salta.html - 이미 번역되어 건너뜀
# ⏭️  argentina-san-luis.html - 이미 번역되어 건너뜀
# ⏭️  argentina-sanjuan.html - 이미 번역되어 건너뜀
# ⏭️  argentina-santafe.html - 이미 번역되어 건너뜀
# ⏭️  argentina-santarosa.html - 이미 번역되어 건너뜀
# ⏭️  argentina-santiago-del-estero.html - 이미 번역되어 건너뜀
# ⏭️  argentina-tucuman.html - 이미 번역되어 건너뜀
# ⏭️  argentina-ushuaia.html - 이미 번역되어 건너뜀
# ⏭️  argentina-jujuy.html - 이미 번역되어 건너뜀
# ⏭️  armenia-alaverdi.html - 이미 번역되어 건너뜀
# ⏭️  armenia-ararat.html - 이미 번역되어 건너뜀
# ⏭️  armenia-armavir.html - 이미 번역되어 건너뜀
# ⏭️  armenia-artashat.html - 이미 번역되어 건너뜀
# ⏭️  armenia-ashtarak.html - 이미 번역되어 건너뜀
# ⏭️  armenia-dilijan.html - 이미 번역되어 건너뜀
# ⏭️  armenia-gavar.html - 이미 번역되어 건너뜀
# ⏭️  armenia-goris.html - 이미 번역되어 건너뜀
# ⏭️  armenia-gyumri.html - 이미 번역되어 건너뜀
# ⏭️  armenia-hrazdan.html - 이미 번역되어 건너뜀
# 📊 진행률: 113/5385 완료
# 📊 진행률: 114/5385 완료
# 📊 진행률: 115/5385 완료
# 📊 진행률: 116/5385 완료
# 📊 진행률: 117/5385 완료
# 📊 진행률: 118/5385 완료
# 📊 진행률: 119/5385 완료
# 📊 진행률: 120/5385 완료
# 📊 진행률: 121/5385 완료
# 📊 진행률: 122/5385 완료
# 📊 진행률: 123/5385 완료
# 📊 진행률: 124/5385 완료
# 📊 진행률: 125/5385 완료
# 📊 진행률: 126/5385 완료
# 📊 진행률: 127/5385 완료
# 📊 진행률: 128/5385 완료
# 📊 진행률: 129/5385 완료
# 📊 진행률: 130/5385 완료
# 📊 진행률: 131/5385 완료
# 📊 진행률: 132/5385 완료
# 📊 진행률: 133/5385 완료
# 📊 진행률: 134/5385 완료
# ⏭️  armenia-kapan.html - 이미 번역되어 건너뜀
# ⏭️  armenia-abovyan.html - 이미 번역되어 건너뜀
# ⏭️  armenia-ijevan.html - 이미 번역되어 건너뜀
# ⏭️  armenia-martuni.html - 이미 번역되어 건너뜀
# ⏭️  armenia-masis.html - 이미 번역되어 건너뜀
# ⏭️  armenia-spitak.html - 이미 번역되어 건너뜀
# ⏭️  armenia-stepanavan.html - 이미 번역되어 건너뜀
# ⏭️  armenia-vagharshapat.html - 이미 번역되어 건너뜀
# ⏭️  armenia-khachavan.html - 이미 번역되어 건너뜀
# 📊 진행률: 135/5385 완료
# 📊 진행률: 136/5385 완료
# 📊 진행률: 137/5385 완료
# 📊 진행률: 138/5385 완료
# 📊 진행률: 139/5385 완료
# 📊 진행률: 140/5385 완료
# 📊 진행률: 141/5385 완료
# 📊 진행률: 142/5385 완료
# 📊 진행률: 143/5385 완료
# ⏭️  armenia-sevan.html - 이미 번역되어 건너뜀
# ⏭️  armenia-vedi.html - 이미 번역되어 건너뜀
# ⏭️  armenia-yeghvard.html - 이미 번역되어 건너뜀
# ⏭️  armenia-yerevan.html - 이미 번역되어 건너뜀
# ⏭️  australia-adelaide.html - 이미 번역되어 건너뜀
# ⏭️  australia-albury.html - 이미 번역되어 건너뜀
# ⏭️  australia-alicesprings.html - 이미 번역되어 건너뜀
# ⏭️  australia-ballarat.html - 이미 번역되어 건너뜀
# ⏭️  australia-bendigo.html - 이미 번역되어 건너뜀
# ⏭️  australia-brisbane.html - 이미 번역되어 건너뜀
# 📊 진행률: 144/5385 완료
# 📊 진행률: 145/5385 완료
# 📊 진행률: 146/5385 완료
# 📊 진행률: 147/5385 완료
# 📊 진행률: 148/5385 완료
# 📊 진행률: 149/5385 완료
# 📊 진행률: 150/5385 완료
# 📊 진행률: 151/5385 완료
# 📊 진행률: 152/5385 완료
# 📊 진행률: 153/5385 완료
# ⏭️  armenia-vanadzor.html - 이미 번역되어 건너뜀
# ⏭️  australia-bundaberg.html - 이미 번역되어 건너뜀
# ⏭️  australia-cairns.html - 이미 번역되어 건너뜀
# ⏭️  australia-canberra.html - 이미 번역되어 건너뜀
# ⏭️  australia-darwin.html - 이미 번역되어 건너뜀
# ⏭️  australia-geelong.html - 이미 번역되어 건너뜀
# ⏭️  armenia-vardenis.html - 이미 번역되어 건너뜀
# ⏭️  australia-goldcoast.html - 이미 번역되어 건너뜀
# ⏭️  australia-hervey-bay.html - 이미 번역되어 건너뜀
# 📊 진행률: 154/5385 완료
# 📊 진행률: 155/5385 완료
# 📊 진행률: 156/5385 완료
# 📊 진행률: 157/5385 완료
# 📊 진행률: 158/5385 완료
# 📊 진행률: 159/5385 완료
# 📊 진행률: 160/5385 완료
# 📊 진행률: 161/5385 완료
# 📊 진행률: 162/5385 완료
# ⏭️  australia-broome.html - 이미 번역되어 건너뜀
# ⏭️  australia-kalgoorlie.html - 이미 번역되어 건너뜀
# ⏭️  australia-launceston.html - 이미 번역되어 건너뜀
# ⏭️  australia-mackay.html - 이미 번역되어 건너뜀
# ⏭️  australia-melbourne.html - 이미 번역되어 건너뜀
# ⏭️  australia-gladstone.html - 이미 번역되어 건너뜀
# ⏭️  australia-hobart.html - 이미 번역되어 건너뜀
# ⏭️  australia-perth.html - 이미 번역되어 건너뜀
# 📊 진행률: 163/5385 완료
# 📊 진행률: 164/5385 완료
# 📊 진행률: 165/5385 완료
# 📊 진행률: 166/5385 완료
# 📊 진행률: 167/5385 완료
# 📊 진행률: 168/5385 완료
# 📊 진행률: 169/5385 완료
# 📊 진행률: 170/5385 완료
# ⏭️  australia-portmacquarie.html - 이미 번역되어 건너뜀
# ⏭️  australia-sunshinecoast.html - 이미 번역되어 건너뜀
# ⏭️  australia-sydney.html - 이미 번역되어 건너뜀
# ⏭️  australia-toowoomba.html - 이미 번역되어 건너뜀
# ⏭️  australia-townsville.html - 이미 번역되어 건너뜀
# ⏭️  australia-wagga.html - 이미 번역되어 건너뜀
# ⏭️  australia-wollongong.html - 이미 번역되어 건너뜀
# ⏭️  austria-amstetten.html - 이미 번역되어 건너뜀
# ⏭️  austria-ansfelden.html - 이미 번역되어 건너뜀
# ⏭️  austria-bad-voeslau.html - 이미 번역되어 건너뜀
# ⏭️  austria-baden.html - 이미 번역되어 건너뜀
# ⏭️  austria-badischl.html - 이미 번역되어 건너뜀
# 📊 진행률: 171/5385 완료
# 📊 진행률: 172/5385 완료
# 📊 진행률: 173/5385 완료
# 📊 진행률: 174/5385 완료
# 📊 진행률: 175/5385 완료
# 📊 진행률: 176/5385 완료
# 📊 진행률: 177/5385 완료
# 📊 진행률: 178/5385 완료
# 📊 진행률: 179/5385 완료
# 📊 진행률: 180/5385 완료
# 📊 진행률: 181/5385 완료
# 📊 진행률: 182/5385 완료
# ⏭️  australia-newcastle.html - 이미 번역되어 건너뜀
# ⏭️  australia-rockhampton.html - 이미 번역되어 건너뜀
# ⏭️  austria-bludenz.html - 이미 번역되어 건너뜀
# ⏭️  austria-braunau.html - 이미 번역되어 건너뜀
# ⏭️  austria-bregenz.html - 이미 번역되어 건너뜀
# ⏭️  austria-bruck.html - 이미 번역되어 건너뜀
# ⏭️  austria-brunn-am-gebirge.html - 이미 번역되어 건너뜀
# ⏭️  austria-dornbirn.html - 이미 번역되어 건너뜀
# ⏭️  austria-eisenstadt.html - 이미 번역되어 건너뜀
# ⏭️  austria-enns.html - 이미 번역되어 건너뜀
# ⏭️  austria-feldkirch.html - 이미 번역되어 건너뜀
# ⏭️  austria-feldkirchen.html - 이미 번역되어 건너뜀
# 📊 진행률: 183/5385 완료
# 📊 진행률: 184/5385 완료
# 📊 진행률: 185/5385 완료
# 📊 진행률: 186/5385 완료
# 📊 진행률: 187/5385 완료
# 📊 진행률: 188/5385 완료
# 📊 진행률: 189/5385 완료
# 📊 진행률: 190/5385 완료
# 📊 진행률: 191/5385 완료
# 📊 진행률: 192/5385 완료
# 📊 진행률: 193/5385 완료
# 📊 진행률: 194/5385 완료
# ⏭️  austria-bischofshofen.html - 이미 번역되어 건너뜀
# ⏭️  austria-graz.html - 이미 번역되어 건너뜀
# ⏭️  austria-hall-in-tirol.html - 이미 번역되어 건너뜀
# ⏭️  austria-hallstatt.html - 이미 번역되어 건너뜀
# ⏭️  austria-hart.html - 이미 번역되어 건너뜀
# 📊 진행률: 195/5385 완료
# 📊 진행률: 196/5385 완료
# 📊 진행률: 197/5385 완료
# 📊 진행률: 198/5385 완료
# 📊 진행률: 199/5385 완료
# ⏭️  austria-gmunden.html - 이미 번역되어 건너뜀
# ⏭️  austria-hohenems.html - 이미 번역되어 건너뜀
# ⏭️  austria-hollabrunn.html - 이미 번역되어 건너뜀
# ⏭️  austria-kapfenberg.html - 이미 번역되어 건너뜀
# 📊 진행률: 200/5385 완료
# 📊 진행률: 201/5385 완료
# 📊 진행률: 202/5385 완료
# 📊 진행률: 203/5385 완료
# ⏭️  austria-innsbruck.html - 이미 번역되어 건너뜀
# ⏭️  austria-gotzis.html - 이미 번역되어 건너뜀
# ⏭️  austria-klagenfurt.html - 이미 번역되어 건너뜀
# 📊 진행률: 204/5385 완료
# 📊 진행률: 205/5385 완료
# 📊 진행률: 206/5385 완료
# ⏭️  austria-klosterneuburg.html - 이미 번역되어 건너뜀
# ⏭️  austria-korneuburg.html - 이미 번역되어 건너뜀
# ⏭️  austria-krems.html - 이미 번역되어 건너뜀
# ⏭️  austria-kufstein.html - 이미 번역되어 건너뜀
# ⏭️  austria-knittelfeld.html - 이미 번역되어 건너뜀
# ⏭️  austria-leonding.html - 이미 번역되어 건너뜀
# ⏭️  austria-lienz.html - 이미 번역되어 건너뜀
# ⏭️  austria-linz.html - 이미 번역되어 건너뜀
# ⏭️  austria-lustenau.html - 이미 번역되어 건너뜀
# ⏭️  austria-marktrenk.html - 이미 번역되어 건너뜀
# ⏭️  austria-mistelbach.html - 이미 번역되어 건너뜀
# ⏭️  austria-modling.html - 이미 번역되어 건너뜀
# ⏭️  austria-neunkirchen.html - 이미 번역되어 건너뜀
# ⏭️  austria-perchtoldsdorf.html - 이미 번역되어 건너뜀
# ⏭️  austria-ried.html - 이미 번역되어 건너뜀
# ⏭️  austria-saalfelden.html - 이미 번역되어 건너뜀
# ⏭️  austria-salzburg.html - 이미 번역되어 건너뜀
# ⏭️  austria-sankt-johann-im-pongau.html - 이미 번역되어 건너뜀
# ⏭️  austria-sankt-veit.html - 이미 번역되어 건너뜀
# ⏭️  austria-schwaz.html - 이미 번역되어 건너뜀
# ⏭️  austria-schwechat.html - 이미 번역되어 건너뜀
# ⏭️  austria-spittal.html - 이미 번역되어 건너뜀
# ⏭️  austria-koflach.html - 이미 번역되어 건너뜀
# ⏭️  austria-steyr.html - 이미 번역되어 건너뜀
# ⏭️  austria-stockerau.html - 이미 번역되어 건너뜀
# ⏭️  austria-stpoelten.html - 이미 번역되어 건너뜀
# ⏭️  austria-telfs.html - 이미 번역되어 건너뜀
# ⏭️  austria-ternitz.html - 이미 번역되어 건너뜀
# ⏭️  austria-traiskirchen.html - 이미 번역되어 건너뜀
# ⏭️  austria-traun.html - 이미 번역되어 건너뜀
# ⏭️  austria-tulln.html - 이미 번역되어 건너뜀
# 📊 진행률: 207/5385 완료
# 📊 진행률: 208/5385 완료
# 📊 진행률: 209/5385 완료
# 📊 진행률: 210/5385 완료
# 📊 진행률: 211/5385 완료
# 📊 진행률: 212/5385 완료
# 📊 진행률: 213/5385 완료
# 📊 진행률: 214/5385 완료
# 📊 진행률: 215/5385 완료
# 📊 진행률: 216/5385 완료
# 📊 진행률: 217/5385 완료
# 📊 진행률: 218/5385 완료
# 📊 진행률: 219/5385 완료
# 📊 진행률: 220/5385 완료
# 📊 진행률: 221/5385 완료
# 📊 진행률: 222/5385 완료
# 📊 진행률: 223/5385 완료
# 📊 진행률: 224/5385 완료
# 📊 진행률: 225/5385 완료
# 📊 진행률: 226/5385 완료
# 📊 진행률: 227/5385 완료
# 📊 진행률: 228/5385 완료
# 📊 진행률: 229/5385 완료
# 📊 진행률: 230/5385 완료
# 📊 진행률: 231/5385 완료
# 📊 진행률: 232/5385 완료
# 📊 진행률: 233/5385 완료
# 📊 진행률: 234/5385 완료
# 📊 진행률: 235/5385 완료
# 📊 진행률: 236/5385 완료
# 📊 진행률: 237/5385 완료
# ⏭️  austria-leoben.html - 이미 번역되어 건너뜀
# ⏭️  austria-vienna.html - 이미 번역되어 건너뜀
# ⏭️  austria-villach.html - 이미 번역되어 건너뜀
# ⏭️  austria-vocklamarkt.html - 이미 번역되어 건너뜀
# ⏭️  austria-voelkermarkt.html - 이미 번역되어 건너뜀
# ⏭️  austria-wals-siezenheim.html - 이미 번역되어 건너뜀
# ⏭️  austria-weithofen.html - 이미 번역되어 건너뜀
# ⏭️  austria-wels.html - 이미 번역되어 건너뜀
# ⏭️  austria-wiener-neustadt.html - 이미 번역되어 건너뜀
# ⏭️  austria-wolfsberg.html - 이미 번역되어 건너뜀
# ⏭️  austria-worgl.html - 이미 번역되어 건너뜀
# ⏭️  austria-zwettl.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-agadara.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-agdam.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-agdash.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-agjabadi.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-agstafa.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-agsu.html - 이미 번역되어 건너뜀
# 📊 진행률: 238/5385 완료
# 📊 진행률: 239/5385 완료
# 📊 진행률: 240/5385 완료
# 📊 진행률: 241/5385 완료
# 📊 진행률: 242/5385 완료
# 📊 진행률: 243/5385 완료
# 📊 진행률: 244/5385 완료
# 📊 진행률: 245/5385 완료
# 📊 진행률: 246/5385 완료
# 📊 진행률: 247/5385 완료
# 📊 진행률: 248/5385 완료
# 📊 진행률: 249/5385 완료
# 📊 진행률: 250/5385 완료
# 📊 진행률: 251/5385 완료
# 📊 진행률: 252/5385 완료
# 📊 진행률: 253/5385 완료
# 📊 진행률: 254/5385 완료
# 📊 진행률: 255/5385 완료
# ⏭️  austria-st-andrae.html - 이미 번역되어 건너뜀
# ⏭️  austria-vienna-schubert.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-babek.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-baku.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-balakan.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-barda.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-beylagan.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-bilasuvar.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-dashkasan.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-fuzuli.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-gabala.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-ganja.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-goranboy.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-goychay.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-imishli.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-astara.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-ismayilli.html - 이미 번역되어 건너뜀
# 📊 진행률: 256/5385 완료
# 📊 진행률: 257/5385 완료
# 📊 진행률: 258/5385 완료
# 📊 진행률: 259/5385 완료
# 📊 진행률: 260/5385 완료
# 📊 진행률: 261/5385 완료
# 📊 진행률: 262/5385 완료
# 📊 진행률: 263/5385 완료
# 📊 진행률: 264/5385 완료
# 📊 진행률: 265/5385 완료
# 📊 진행률: 266/5385 완료
# 📊 진행률: 267/5385 완료
# 📊 진행률: 268/5385 완료
# 📊 진행률: 269/5385 완료
# 📊 진행률: 270/5385 완료
# 📊 진행률: 271/5385 완료
# 📊 진행률: 272/5385 완료
# ⏭️  azerbaijan-jabrayil.html - 이미 번역되어 건너뜀
# 📊 진행률: 273/5385 완료
# ⏭️  azerbaijan-kalbajar.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-khachmaz.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-khankendi.html - 이미 번역되어 건너뜀
# 📊 진행률: 274/5385 완료
# 📊 진행률: 275/5385 완료
# 📊 진행률: 276/5385 완료
# ⏭️  azerbaijan-goygol.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-kurdamir.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-lankaran.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-lerik.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-masalli.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-mingachevir.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-naftalan.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-nakhchivan.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-neftchala.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-oguz.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-ordubad.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-qakh.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-qazanbend.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-qirdalan.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-quba.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-qusar.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-sabirabad.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-satli.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-julfa.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-khazgabul.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-shabran.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-shabuz.html - 이미 번역되어 건너뜀
# 📊 진행률: 277/5385 완료
# 📊 진행률: 278/5385 완료
# 📊 진행률: 279/5385 완료
# 📊 진행률: 280/5385 완료
# 📊 진행률: 281/5385 완료
# 📊 진행률: 282/5385 완료
# 📊 진행률: 283/5385 완료
# 📊 진행률: 284/5385 완료
# 📊 진행률: 285/5385 완료
# 📊 진행률: 286/5385 완료
# 📊 진행률: 287/5385 완료
# 📊 진행률: 288/5385 완료
# 📊 진행률: 289/5385 완료
# 📊 진행률: 290/5385 완료
# 📊 진행률: 291/5385 완료
# 📊 진행률: 292/5385 완료
# 📊 진행률: 293/5385 완료
# 📊 진행률: 294/5385 완료
# 📊 진행률: 295/5385 완료
# 📊 진행률: 296/5385 완료
# 📊 진행률: 297/5385 완료
# 📊 진행률: 298/5385 완료
# ⏭️  azerbaijan-sharur.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-sheki.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-shirvan.html - 이미 번역되어 건너뜀
# 📊 진행률: 299/5385 완료
# 📊 진행률: 300/5385 완료
# 📊 진행률: 301/5385 완료
# ⏭️  azerbaijan-shamakhi.html - 이미 번역되어 건너뜀
# 📊 진행률: 302/5385 완료
# ⏭️  azerbaijan-shusha.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-shamkir.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-sumgait.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-tovus.html - 이미 번역되어 건너뜀
# 📊 진행률: 303/5385 완료
# 📊 진행률: 304/5385 완료
# 📊 진행률: 305/5385 완료
# 📊 진행률: 306/5385 완료
# ⏭️  azerbaijan-udjar.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-yevlax.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-zangilan.html - 이미 번역되어 건너뜀
# 📊 진행률: 307/5385 완료
# 📊 진행률: 308/5385 완료
# 📊 진행률: 309/5385 완료
# ⏭️  azerbaijan-yardimli.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-zardab.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-alice-town.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-andros.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-arthurs-town.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-cockburn-town.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-cooperstown.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-dunmore-town.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-freeport.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-governors-harbour.html - 이미 번역되어 건너뜀
# ⏭️  azerbaijan-siyazan.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-marsh-harbour.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-matthew-town.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-nassau.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-nicholstown.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-rocksound.html - 이미 번역되어 건너뜀
# ⏭️  bahamas-spanish-wells.html - 이미 번역되어 건너뜀
# ⏭️  bahrain-aali.html - 이미 번역되어 건너뜀
# ⏭️  bahrain-budaiya.html - 이미 번역되어 건너뜀
# ⏭️  bahrain-duraz.html - 이미 번역되어 건너뜀
# ⏭️  bahrain-hamad-town.html - 이미 번역되어 건너뜀
# ⏭️  bahrain-isa-town.html - 이미 번역되어 건너뜀
# ⏭️  bahrain-jidhafs.html - 이미 번역되어 건너뜀
# ⏭️  bahrain-karbabad.html - 이미 번역되어 건너뜀
# ⏭️  bahrain-manama.html - 이미 번역되어 건너뜀
# 📊 진행률: 310/5385 완료
# 📊 진행률: 311/5385 완료
# 📊 진행률: 312/5385 완료
# 📊 진행률: 313/5385 완료
# 📊 진행률: 314/5385 완료
# 📊 진행률: 315/5385 완료
# 📊 진행률: 316/5385 완료
# 📊 진행률: 317/5385 완료
# 📊 진행률: 318/5385 완료
# 📊 진행률: 319/5385 완료
# 📊 진행률: 320/5385 완료
# 📊 진행률: 321/5385 완료
# 📊 진행률: 322/5385 완료
# 📊 진행률: 323/5385 완료
# 📊 진행률: 324/5385 완료
# 📊 진행률: 325/5385 완료
# 📊 진행률: 326/5385 완료
# 📊 진행률: 327/5385 완료
# 📊 진행률: 328/5385 완료
# 📊 진행률: 329/5385 완료
# 📊 진행률: 330/5385 완료
# 📊 진행률: 331/5385 완료
# 📊 진행률: 332/5385 완료
# 📊 진행률: 333/5385 완료
# 📊 진행률: 334/5385 완료
# ⏭️  azerbaijan-zaqatala.html - 이미 번역되어 건너뜀
# ⏭️  bahrain-riffa.html - 이미 번역되어 건너뜀
# 📊 진행률: 335/5385 완료
# 📊 진행률: 336/5385 완료
# ⏭️  bahamas-hailock.html - 이미 번역되어 건너뜀
# ⏭️  bahrain-sitra.html - 이미 번역되어 건너뜀
# ⏭️  bahrain-muharraq.html - 이미 번역되어 건너뜀
# ⏭️  bahrain-tubli.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-bandarban.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-barisal.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-bogra.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-brahmanbaria.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-chandpur.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-chapainawabganj.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-chittagong.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-comilla.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-coxsbazar.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-dhaka.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-dinajpur.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-faridpur.html - 이미 번역되어 건너뜀
# 📊 진행률: 337/5385 완료
# 📊 진행률: 338/5385 완료
# 📊 진행률: 339/5385 완료
# 📊 진행률: 340/5385 완료
# 📊 진행률: 341/5385 완료
# 📊 진행률: 342/5385 완료
# 📊 진행률: 343/5385 완료
# 📊 진행률: 344/5385 완료
# 📊 진행률: 345/5385 완료
# 📊 진행률: 346/5385 완료
# 📊 진행률: 347/5385 완료
# 📊 진행률: 348/5385 완료
# 📊 진행률: 349/5385 완료
# 📊 진행률: 350/5385 완료
# 📊 진행률: 351/5385 완료
# 📊 진행률: 352/5385 완료
# ⏭️  bangladesh-gaibandha.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-barguna.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-gazipur.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-gopalganj.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-habiganj.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-jamalpur.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-jessore.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-jhalokati.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-joypurhat.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-khagrachari.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-feni.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-kishoreganj.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-kurigram.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-kushtia.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-lakshmipur.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-lalmonirhat.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-madaripur.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-magura.html - 이미 번역되어 건너뜀
# 📊 진행률: 353/5385 완료
# 📊 진행률: 354/5385 완료
# 📊 진행률: 355/5385 완료
# 📊 진행률: 356/5385 완료
# 📊 진행률: 357/5385 완료
# 📊 진행률: 358/5385 완료
# 📊 진행률: 359/5385 완료
# 📊 진행률: 360/5385 완료
# 📊 진행률: 361/5385 완료
# 📊 진행률: 362/5385 완료
# 📊 진행률: 363/5385 완료
# 📊 진행률: 364/5385 완료
# 📊 진행률: 365/5385 완료
# 📊 진행률: 366/5385 완료
# 📊 진행률: 367/5385 완료
# 📊 진행률: 368/5385 완료
# 📊 진행률: 369/5385 완료
# 📊 진행률: 370/5385 완료
# ⏭️  bangladesh-khulna.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-naogaon.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-narayanganj.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-mymensingh.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-meherpur.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-nilphamari.html - 이미 번역되어 건너뜀
# 📊 진행률: 371/5385 완료
# 📊 진행률: 372/5385 완료
# 📊 진행률: 373/5385 완료
# 📊 진행률: 374/5385 완료
# 📊 진행률: 375/5385 완료
# 📊 진행률: 376/5385 완료
# ⏭️  bangladesh-netrokona.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-pabna.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-panchagarh.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-patuakhali.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-pirojpur.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-rajshahi.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-rangamati.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-rangpur.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-satkhira.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-shariatpur.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-sherpur.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-narsingdi.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-noakhali.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-sylhet.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-sirajganj.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-tangail.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-thakurgaon.html - 이미 번역되어 건너뜀
# ⏭️  barbados-bathsheba.html - 이미 번역되어 건너뜀
# ⏭️  barbados-bridgetown.html - 이미 번역되어 건너뜀
# ⏭️  bangladesh-sunamganj.html - 이미 번역되어 건너뜀
# ⏭️  barbados-diamond-valley.html - 이미 번역되어 건너뜀
# 📊 진행률: 377/5385 완료
# 📊 진행률: 378/5385 완료
# 📊 진행률: 379/5385 완료
# 📊 진행률: 380/5385 완료
# 📊 진행률: 381/5385 완료
# 📊 진행률: 382/5385 완료
# 📊 진행률: 383/5385 완료
# 📊 진행률: 384/5385 완료
# 📊 진행률: 385/5385 완료
# 📊 진행률: 386/5385 완료
# 📊 진행률: 387/5385 완료
# 📊 진행률: 388/5385 완료
# 📊 진행률: 389/5385 완료
# 📊 진행률: 390/5385 완료
# 📊 진행률: 391/5385 완료
# 📊 진행률: 392/5385 완료
# 📊 진행률: 393/5385 완료
# 📊 진행률: 394/5385 완료
# 📊 진행률: 395/5385 완료
# 📊 진행률: 396/5385 완료
# 📊 진행률: 397/5385 완료
# ⏭️  barbados-curtains.html - 이미 번역되어 건너뜀
# ⏭️  barbados-gibbs.html - 이미 번역되어 건너뜀
# ⏭️  barbados-holetown.html - 이미 번역되어 건너뜀
# ⏭️  barbados-fitts-village.html - 이미 번역되어 건너뜀
# ⏭️  barbados-durants.html - 이미 번역되어 건너뜀
# ⏭️  barbados-oistins.html - 이미 번역되어 건너뜀
# ⏭️  barbados-porters.html - 이미 번역되어 건너뜀
# ⏭️  barbados-prospect.html - 이미 번역되어 건너뜀
# ⏭️  barbados-speightstown.html - 이미 번역되어 건너뜀
# ⏭️  barbados-stmartins.html - 이미 번역되어 건너뜀
# ⏭️  barbados-thegarden.html - 이미 번역되어 건너뜀
# ⏭️  barbados-welchman-hall.html - 이미 번역되어 건너뜀
# ⏭️  barbados-western.html - 이미 번역되어 건너뜀
# 📊 진행률: 398/5385 완료
# 📊 진행률: 399/5385 완료
# 📊 진행률: 400/5385 완료
# 📊 진행률: 401/5385 완료
# 📊 진행률: 402/5385 완료
# 📊 진행률: 403/5385 완료
# 📊 진행률: 404/5385 완료
# 📊 진행률: 405/5385 완료
# 📊 진행률: 406/5385 완료
# 📊 진행률: 407/5385 완료
# 📊 진행률: 408/5385 완료
# 📊 진행률: 409/5385 완료
# 📊 진행률: 410/5385 완료
# ⏭️  barbados-lower-carlton.html - 이미 번역되어 건너뜀
# ⏭️  belarus-babruysk.html - 이미 번역되어 건너뜀
# ⏭️  belarus-baranovichi.html - 이미 번역되어 건너뜀
# ⏭️  barbados-mullins.html - 이미 번역되어 건너뜀
# 📊 진행률: 411/5385 완료
# 📊 진행률: 412/5385 완료
# 📊 진행률: 413/5385 완료
# 📊 진행률: 414/5385 완료
# ⏭️  belarus-bereiki.html - 이미 번역되어 건너뜀
# ⏭️  belarus-bereyki.html - 이미 번역되어 건너뜀
# ⏭️  belarus-antopal.html - 이미 번역되어 건너뜀
# ⏭️  belarus-bobruisk.html - 이미 번역되어 건너뜀
# ⏭️  belarus-bereza.html - 이미 번역되어 건너뜀
# ⏭️  belarus-bragin.html - 이미 번역되어 건너뜀
# ⏭️  belarus-braslav.html - 이미 번역되어 건너뜀
# ⏭️  belarus-brest.html - 이미 번역되어 건너뜀
# ⏭️  belarus-budakoshelevo.html - 이미 번역되어 건너뜀
# ⏭️  belarus-chechersk.html - 이미 번역되어 건너뜀
# ⏭️  belarus-cherey.html - 이미 번역되어 건너뜀
# ⏭️  belarus-boroni.html - 이미 번역되어 건너뜀
# ⏭️  belarus-cherni.html - 이미 번역되어 건너뜀
# 📊 진행률: 415/5385 완료
# 📊 진행률: 416/5385 완료
# 📊 진행률: 417/5385 완료
# 📊 진행률: 418/5385 완료
# 📊 진행률: 419/5385 완료
# 📊 진행률: 420/5385 완료
# 📊 진행률: 421/5385 완료
# 📊 진행률: 422/5385 완료
# 📊 진행률: 423/5385 완료
# 📊 진행률: 424/5385 완료
# 📊 진행률: 425/5385 완료
# 📊 진행률: 426/5385 완료
# 📊 진행률: 427/5385 완료
# ⏭️  belarus-chernivtsi.html - 이미 번역되어 건너뜀
# ⏭️  belarus-cherykaw.html - 이미 번역되어 건너뜀
# ⏭️  belarus-chesky.html - 이미 번역되어 건너뜀
# ⏭️  belarus-cherikov.html - 이미 번역되어 건너뜀
# ⏭️  belarus-chervyen.html - 이미 번역되어 건너뜀
# ⏭️  belarus-drahichyn.html - 이미 번역되어 건너뜀
# ⏭️  belarus-drohichin.html - 이미 번역되어 건너뜀
# ⏭️  belarus-dubrovno.html - 이미 번역되어 건너뜀
# ⏭️  belarus-dubrovny.html - 이미 번역되어 건너뜀
# ⏭️  belarus-dubrowna.html - 이미 번역되어 건너뜀
# ⏭️  belarus-elsk.html - 이미 번역되어 건너뜀
# ⏭️  belarus-eshimontovich.html - 이미 번역되어 건너뜀
# ⏭️  belarus-gantsevichi.html - 이미 번역되어 건너뜀
# ⏭️  belarus-glubokoe.html - 이미 번역되어 건너뜀
# ⏭️  belarus-glubokoye.html - 이미 번역되어 건너뜀
# ⏭️  belarus-glusk.html - 이미 번역되어 건너뜀
# ⏭️  belarus-gomel.html - 이미 번역되어 건너뜀
# ⏭️  belarus-gorodok.html - 이미 번역되어 건너뜀
# 📊 진행률: 428/5385 완료
# 📊 진행률: 429/5385 완료
# 📊 진행률: 430/5385 완료
# 📊 진행률: 431/5385 완료
# 📊 진행률: 432/5385 완료
# 📊 진행률: 433/5385 완료
# 📊 진행률: 434/5385 완료
# 📊 진행률: 435/5385 완료
# 📊 진행률: 436/5385 완료
# 📊 진행률: 437/5385 완료
# 📊 진행률: 438/5385 완료
# 📊 진행률: 439/5385 완료
# 📊 진행률: 440/5385 완료
# 📊 진행률: 441/5385 완료
# 📊 진행률: 442/5385 완료
# 📊 진행률: 443/5385 완료
# 📊 진행률: 444/5385 완료
# 📊 진행률: 445/5385 완료
# ⏭️  belarus-dokshitsy.html - 이미 번역되어 건너뜀
# ⏭️  belarus-ivanko.html - 이미 번역되어 건너뜀
# ⏭️  belarus-ivanovo.html - 이미 번역되어 건너뜀
# ⏭️  belarus-ivatsevichi.html - 이미 번역되어 건너뜀
# ⏭️  belarus-ivatsevichy.html - 이미 번역되어 건너뜀
# ⏭️  belarus-kalinkavichy.html - 이미 번역되어 건너뜀
# ⏭️  belarus-kamen.html - 이미 번역되어 건너뜀
# ⏭️  belarus-karelichy.html - 이미 번역되어 건너뜀
# ⏭️  belarus-karichi.html - 이미 번역되어 건너뜀
# ⏭️  belarus-kirovsk.html - 이미 번역되어 건너뜀
# ⏭️  belarus-kletsk.html - 이미 번역되어 건너뜀
# ⏭️  belarus-klimovichi.html - 이미 번역되어 건너뜀
# ⏭️  belarus-kobrin.html - 이미 번역되어 건너뜀
# ⏭️  belarus-kostyukovichi.html - 이미 번역되어 건너뜀
# ⏭️  belarus-krasnapollye.html - 이미 번역되어 건너뜀
# 📊 진행률: 446/5385 완료
# 📊 진행률: 447/5385 완료
# 📊 진행률: 448/5385 완료
# 📊 진행률: 449/5385 완료
# 📊 진행률: 450/5385 완료
# 📊 진행률: 451/5385 완료
# 📊 진행률: 452/5385 완료
# 📊 진행률: 453/5385 완료
# 📊 진행률: 454/5385 완료
# 📊 진행률: 455/5385 완료
# 📊 진행률: 456/5385 완료
# 📊 진행률: 457/5385 완료
# 📊 진행률: 458/5385 완료
# 📊 진행률: 459/5385 완료
# 📊 진행률: 460/5385 완료
# ⏭️  belarus-dobrush.html - 이미 번역되어 건너뜀
# ⏭️  belarus-krichev.html - 이미 번역되어 건너뜀
# 📊 진행률: 461/5385 완료
# 📊 진행률: 462/5385 완료
# ⏭️  belarus-krugloe.html - 이미 번역되어 건너뜀
# ⏭️  belarus-grodno.html - 이미 번역되어 건너뜀
# ⏭️  belarus-krupa.html - 이미 번역되어 건너뜀
# ⏭️  belarus-lahoisk.html - 이미 번역되어 건너뜀
# 📊 진행률: 463/5385 완료
# 📊 진행률: 464/5385 완료
# 📊 진행률: 465/5385 완료
# 📊 진행률: 466/5385 완료
# ⏭️  belarus-lepel.html - 이미 번역되어 건너뜀
# ⏭️  belarus-lagoysk.html - 이미 번역되어 건너뜀
# ⏭️  belarus-lida.html - 이미 번역되어 건너뜀
# ⏭️  belarus-liozhno.html - 이미 번역되어 건너뜀
# ⏭️  belarus-liozno.html - 이미 번역되어 건너뜀
# ⏭️  belarus-lukoml.html - 이미 번역되어 건너뜀
# 📊 진행률: 467/5385 완료
# 📊 진행률: 468/5385 완료
# 📊 진행률: 469/5385 완료
# 📊 진행률: 470/5385 완료
# 📊 진행률: 471/5385 완료
# 📊 진행률: 472/5385 완료
# ⏭️  belarus-malaryta.html - 이미 번역되어 건너뜀
# ⏭️  belarus-luzhki.html - 이미 번역되어 건너뜀
# ⏭️  belarus-malorita.html - 이미 번역되어 건너뜀
# ⏭️  belarus-krasnopolye.html - 이미 번역되어 건너뜀
# ⏭️  belarus-markovich.html - 이미 번역되어 건너뜀
# ⏭️  belarus-markovichi.html - 이미 번역되어 건너뜀
# ⏭️  belarus-minsk.html - 이미 번역되어 건너뜀
# ⏭️  belarus-miory.html - 이미 번역되어 건너뜀
# ⏭️  belarus-mir.html - 이미 번역되어 건너뜀
# ⏭️  belarus-mogilev.html - 이미 번역되어 건너뜀
# ⏭️  belarus-mosty.html - 이미 번역되어 건너뜀
# ⏭️  belarus-mozyr.html - 이미 번역되어 건너뜀
# ⏭️  belarus-mukachevo.html - 이미 번역되어 건너뜀
# ⏭️  belarus-narobria.html - 이미 번역되어 건너뜀
# ⏭️  belarus-narowlya.html - 이미 번역되어 건너뜀
# ⏭️  belarus-nesvizh.html - 이미 번역되어 건너뜀
# ⏭️  belarus-novogrudok.html - 이미 번역되어 건너뜀
# ⏭️  belarus-novopolotsk.html - 이미 번역되어 건너뜀
# ⏭️  belarus-orsha.html - 이미 번역되어 건너뜀
# ⏭️  belarus-ostrovets.html - 이미 번역되어 건너뜀
# ⏭️  belarus-panino.html - 이미 번역되어 건너뜀
# ⏭️  belarus-parich.html - 이미 번역되어 건너뜀
# ⏭️  belarus-parichi.html - 이미 번역되어 건너뜀
# ⏭️  belarus-petrikau.html - 이미 번역되어 건너뜀
# 📊 진행률: 473/5385 완료
# 📊 진행률: 474/5385 완료
# 📊 진행률: 475/5385 완료
# 📊 진행률: 476/5385 완료
# 📊 진행률: 477/5385 완료
# 📊 진행률: 478/5385 완료
# 📊 진행률: 479/5385 완료
# 📊 진행률: 480/5385 완료
# 📊 진행률: 481/5385 완료
# 📊 진행률: 482/5385 완료
# 📊 진행률: 483/5385 완료
# 📊 진행률: 484/5385 완료
# 📊 진행률: 485/5385 완료
# 📊 진행률: 486/5385 완료
# 📊 진행률: 487/5385 완료
# 📊 진행률: 488/5385 완료
# 📊 진행률: 489/5385 완료
# 📊 진행률: 490/5385 완료
# 📊 진행률: 491/5385 완료
# 📊 진행률: 492/5385 완료
# 📊 진행률: 493/5385 완료
# 📊 진행률: 494/5385 완료
# 📊 진행률: 495/5385 완료
# 📊 진행률: 496/5385 완료
# ⏭️  belarus-marjina-horka.html - 이미 번역되어 건너뜀
# 📊 진행률: 497/5385 완료
# ⏭️  belarus-petrikov.html - 이미 번역되어 건너뜀
# ⏭️  belarus-polotsk.html - 이미 번역되어 건너뜀
# 📊 진행률: 498/5385 완료
# 📊 진행률: 499/5385 완료
# ⏭️  belarus-pinsk.html - 이미 번역되어 건너뜀
# ⏭️  belarus-postavy.html - 이미 번역되어 건너뜀
# ⏭️  belarus-priluki.html - 이미 번역되어 건너뜀
# ⏭️  belarus-pruzhany.html - 이미 번역되어 건너뜀
# ⏭️  belarus-radoshkovich.html - 이미 번역되어 건너뜀
# 📊 진행률: 500/5385 완료
# 📊 진행률: 501/5385 완료
# 📊 진행률: 502/5385 완료
# 📊 진행률: 503/5385 완료
# 📊 진행률: 504/5385 완료
# ⏭️  belarus-radoshkovichi.html - 이미 번역되어 건너뜀
# ⏭️  belarus-rechitsa.html - 이미 번역되어 건너뜀
# ⏭️  belarus-rubesha.html - 이미 번역되어 건너뜀
# ⏭️  belarus-rubezha.html - 이미 번역되어 건너뜀
# ⏭️  belarus-shchuchyn.html - 이미 번역되어 건너뜀
# ⏭️  belarus-sharkovshchina.html - 이미 번역되어 건너뜀
# ⏭️  belarus-rogachev.html - 이미 번역되어 건너뜀
# ⏭️  belarus-sinyavka.html - 이미 번역되어 건너뜀
# ⏭️  belarus-shklow.html - 이미 번역되어 건너뜀
# ⏭️  belarus-soligorsk.html - 이미 번역되어 건너뜀
# ⏭️  belarus-stolin.html - 이미 번역되어 건너뜀
# ⏭️  belarus-slonim.html - 이미 번역되어 건너뜀
# ⏭️  belarus-svetlogorsk.html - 이미 번역되어 건너뜀
# ⏭️  belarus-telehani.html - 이미 번역되어 건너뜀
# ⏭️  belarus-telehany.html - 이미 번역되어 건너뜀
# ⏭️  belarus-smolevichi.html - 이미 번역되어 건너뜀
# ⏭️  belarus-torokani.html - 이미 번역되어 건너뜀
# ⏭️  belarus-stolins.html - 이미 번역되어 건너뜀
# ⏭️  belarus-turov.html - 이미 번역되어 건너뜀
# ⏭️  belarus-ushachy.html - 이미 번역되어 건너뜀
# ⏭️  belarus-ushachi.html - 이미 번역되어 건너뜀
# ⏭️  belarus-vawkavysk.html - 이미 번역되어 건너뜀
# 📊 진행률: 505/5385 완료
# 📊 진행률: 506/5385 완료
# 📊 진행률: 507/5385 완료
# 📊 진행률: 508/5385 완료
# 📊 진행률: 509/5385 완료
# 📊 진행률: 510/5385 완료
# 📊 진행률: 511/5385 완료
# 📊 진행률: 512/5385 완료
# 📊 진행률: 513/5385 완료
# 📊 진행률: 514/5385 완료
# 📊 진행률: 515/5385 완료
# 📊 진행률: 516/5385 완료
# 📊 진행률: 517/5385 완료
# 📊 진행률: 518/5385 완료
# 📊 진행률: 519/5385 완료
# 📊 진행률: 520/5385 완료
# 📊 진행률: 521/5385 완료
# 📊 진행률: 522/5385 완료
# 📊 진행률: 523/5385 완료
# 📊 진행률: 524/5385 완료
# 📊 진행률: 525/5385 완료
# 📊 진행률: 526/5385 완료
# ⏭️  belarus-veraun.html - 이미 번역되어 건너뜀
# 📊 진행률: 527/5385 완료
# ⏭️  belarus-vetka.html - 이미 번역되어 건너뜀
# ⏭️  belarus-voronovo.html - 이미 번역되어 건너뜀
# ⏭️  belarus-vysokaye.html - 이미 번역되어 건너뜀
# ⏭️  belarus-vysokoye.html - 이미 번역되어 건너뜀
# ⏭️  belarus-zhytkavichy.html - 이미 번역되어 건너뜀
# ⏭️  belgium-aalst.html - 이미 번역되어 건너뜀
# ⏭️  belgium-antwerp.html - 이미 번역되어 건너뜀
# ⏭️  belgium-arden.html - 이미 번역되어 건너뜀
# ⏭️  belgium-brasschaat.html - 이미 번역되어 건너뜀
# ⏭️  belgium-bruges.html - 이미 번역되어 건너뜀
# ⏭️  belgium-brussels.html - 이미 번역되어 건너뜀
# ⏭️  belarus-volkovysk.html - 이미 번역되어 건너뜀
# ⏭️  belgium-dendermonde.html - 이미 번역되어 건너뜀
# 📊 진행률: 528/5385 완료
# 📊 진행률: 529/5385 완료
# 📊 진행률: 530/5385 완료
# 📊 진행률: 531/5385 완료
# 📊 진행률: 532/5385 완료
# 📊 진행률: 533/5385 완료
# 📊 진행률: 534/5385 완료
# 📊 진행률: 535/5385 완료
# 📊 진행률: 536/5385 완료
# 📊 진행률: 537/5385 완료
# 📊 진행률: 538/5385 완료
# 📊 진행률: 539/5385 완료
# 📊 진행률: 540/5385 완료
# ⏭️  belgium-dinant.html - 이미 번역되어 건너뜀
# ⏭️  belgium-dunkirk.html - 이미 번역되어 건너뜀
# 📊 진행률: 541/5385 완료
# 📊 진행률: 542/5385 완료
# ⏭️  belarus-vitebsk.html - 이미 번역되어 건너뜀
# 📊 진행률: 543/5385 완료
# ⏭️  belgium-hasselt.html - 이미 번역되어 건너뜀
# 📊 진행률: 544/5385 완료
# ⏭️  belgium-herstal.html - 이미 번역되어 건너뜀
# 📊 진행률: 545/5385 완료
# ⏭️  belgium-kortrijk.html - 이미 번역되어 건너뜀
# 📊 진행률: 546/5385 완료
# ⏭️  belgium-lalouviere.html - 이미 번역되어 건너뜀
# 📊 진행률: 547/5385 완료
# ⏭️  belgium-leuven.html - 이미 번역되어 건너뜀
# 📊 진행률: 548/5385 완료
# ⏭️  belgium-liege.html - 이미 번역되어 건너뜀
# 📊 진행률: 549/5385 완료
# ⏭️  belgium-lokeren.html - 이미 번역되어 건너뜀
# 📊 진행률: 550/5385 완료
# ⏭️  belgium-maasmechelen.html - 이미 번역되어 건너뜀
# 📊 진행률: 551/5385 완료
# ⏭️  belgium-mechelen.html - 이미 번역되어 건너뜀
# 📊 진행률: 552/5385 완료
# ⏭️  belgium-charleroi.html - 이미 번역되어 건너뜀
# 📊 진행률: 553/5385 완료
# ⏭️  belgium-namur.html - 이미 번역되어 건너뜀
# 📊 진행률: 554/5385 완료
# ⏭️  belgium-ostend.html - 이미 번역되어 건너뜀
# 📊 진행률: 555/5385 완료
# ⏭️  belgium-sint-niklaas.html - 이미 번역되어 건너뜀
# 📊 진행률: 556/5385 완료
# ⏭️  belgium-sint-truiden.html - 이미 번역되어 건너뜀
# 📊 진행률: 557/5385 완료
# ⏭️  belgium-tielt.html - 이미 번역되어 건너뜀
# 📊 진행률: 558/5385 완료
# ⏭️  belgium-tournai.html - 이미 번역되어 건너뜀
# 📊 진행률: 559/5385 완료
# ⏭️  belgium-vilvoorde.html - 이미 번역되어 건너뜀
# ⏭️  belgium-mons.html - 이미 번역되어 건너뜀
# ⏭️  belize-belmopan.html - 이미 번역되어 건너뜀
# ⏭️  belize-city.html - 이미 번역되어 건너뜀
# ⏭️  belize-corozal.html - 이미 번역되어 건너뜀
# ⏭️  belize-dangriga.html - 이미 번역되어 건너뜀
# ⏭️  belize-orange-walk.html - 이미 번역되어 건너뜀
# ⏭️  belize-punta-gorda.html - 이미 번역되어 건너뜀
# ⏭️  belize-san-ignacio.html - 이미 번역되어 건너뜀
# ⏭️  benin-abeokuta.html - 이미 번역되어 건너뜀
# ⏭️  benin-agoe.html - 이미 번역되어 건너뜀
# ⏭️  benin-agoue.html - 이미 번역되어 건너뜀
# ⏭️  benin-allada.html - 이미 번역되어 건너뜀
# ⏭️  benin-aplahoue.html - 이미 번역되어 건너뜀
# ⏭️  benin-atlantique.html - 이미 번역되어 건너뜀
# ⏭️  benin-azove.html - 이미 번역되어 건너뜀
# ⏭️  benin-banikoara.html - 이미 번역되어 건너뜀
# ⏭️  benin-bassila.html - 이미 번역되어 건너뜀
# ⏭️  benin-bohicon.html - 이미 번역되어 건너뜀
# 📊 진행률: 560/5385 완료
# 📊 진행률: 561/5385 완료
# 📊 진행률: 562/5385 완료
# 📊 진행률: 563/5385 완료
# 📊 진행률: 564/5385 완료
# 📊 진행률: 565/5385 완료
# 📊 진행률: 566/5385 완료
# 📊 진행률: 567/5385 완료
# 📊 진행률: 568/5385 완료
# 📊 진행률: 569/5385 완료
# 📊 진행률: 570/5385 완료
# 📊 진행률: 571/5385 완료
# 📊 진행률: 572/5385 완료
# 📊 진행률: 573/5385 완료
# 📊 진행률: 574/5385 완료
# 📊 진행률: 575/5385 완료
# 📊 진행률: 576/5385 완료
# 📊 진행률: 577/5385 완료
# 📊 진행률: 578/5385 완료
# ⏭️  belgium-ghent.html - 이미 번역되어 건너뜀
# ⏭️  benin-bonde.html - 이미 번역되어 건너뜀
# ⏭️  belgium-ypres.html - 이미 번역되어 건너뜀
# ⏭️  benin-cobri.html - 이미 번역되어 건너뜀
# ⏭️  benin-come.html - 이미 번역되어 건너뜀
# ⏭️  benin-coppang.html - 이미 번역되어 건너뜀
# ⏭️  benin-cotonou.html - 이미 번역되어 건너뜀
# ⏭️  benin-dassa-zoume.html - 이미 번역되어 건너뜀
# ⏭️  benin-deme.html - 이미 번역되어 건너뜀
# ⏭️  benin-copanga.html - 이미 번역되어 건너뜀
# ⏭️  benin-djeme.html - 이미 번역되어 건너뜀
# ⏭️  benin-djaki.html - 이미 번역되어 건너뜀
# 📊 진행률: 579/5385 완료
# 📊 진행률: 580/5385 완료
# 📊 진행률: 581/5385 완료
# 📊 진행률: 582/5385 완료
# 📊 진행률: 583/5385 완료
# 📊 진행률: 584/5385 완료
# 📊 진행률: 585/5385 완료
# 📊 진행률: 586/5385 완료
# 📊 진행률: 587/5385 완료
# 📊 진행률: 588/5385 완료
# 📊 진행률: 589/5385 완료
# 📊 진행률: 590/5385 완료
# ⏭️  benin-djakotomey.html - 이미 번역되어 건너뜀
# ⏭️  benin-foundji.html - 이미 번역되어 건너뜀
# ⏭️  benin-dome.html - 이미 번역되어 건너뜀
# 📊 진행률: 591/5385 완료
# 📊 진행률: 592/5385 완료
# 📊 진행률: 593/5385 완료
# ⏭️  benin-dogbo.html - 이미 번역되어 건너뜀
# ⏭️  benin-godomey.html - 이미 번역되어 건너뜀
# 📊 진행률: 594/5385 완료
# 📊 진행률: 595/5385 완료
# ⏭️  benin-ganvie.html - 이미 번역되어 건너뜀
# ⏭️  benin-goeme.html - 이미 번역되어 건너뜀
# 📊 진행률: 596/5385 완료
# 📊 진행률: 597/5385 완료
# ⏭️  benin-grand-popo.html - 이미 번역되어 건너뜀
# ⏭️  benin-grandpopo.html - 이미 번역되어 건너뜀
# ⏭️  benin-hueyo-gabe.html - 이미 번역되어 건너뜀
# ⏭️  benin-ifehe.html - 이미 번역되어 건너뜀
# ⏭️  benin-jakutome.html - 이미 번역되어 건너뜀
# ⏭️  benin-kandi.html - 이미 번역되어 건너뜀
# ⏭️  benin-kome.html - 이미 번역되어 건너뜀
# ⏭️  benin-kpomasse.html - 이미 번역되어 건너뜀
# ⏭️  benin-lagos.html - 이미 번역되어 건너뜀
# ⏭️  benin-hettine.html - 이미 번역되어 건너뜀
# ⏭️  benin-liberte.html - 이미 번역되어 건너뜀
# ⏭️  benin-malanville.html - 이미 번역되어 건너뜀
# ⏭️  benin-materi.html - 이미 번역되어 건너뜀
# ⏭️  benin-mono.html - 이미 번역되어 건너뜀
# ⏭️  benin-natitingou.html - 이미 번역되어 건너뜀
# ⏭️  benin-nikki.html - 이미 번역되어 건너뜀
# ⏭️  benin-okepara.html - 이미 번역되어 건너뜀
# ⏭️  benin-ouake.html - 이미 번역되어 건너뜀
# ⏭️  benin-ouidah.html - 이미 번역되어 건너뜀
# ⏭️  benin-parakou.html - 이미 번역되어 건너뜀
# ⏭️  benin-pave.html - 이미 번역되어 건너뜀
# ⏭️  benin-penze.html - 이미 번역되어 건너뜀
# ⏭️  benin-portonovo.html - 이미 번역되어 건너뜀
# ⏭️  benin-sakete.html - 이미 번역되어 건너뜀
# ⏭️  benin-savalou.html - 이미 번역되어 건너뜀
# ⏭️  benin-savanna.html - 이미 번역되어 건너뜀
# ⏭️  benin-save.html - 이미 번역되어 건너뜀
# ⏭️  benin-segboue.html - 이미 번역되어 건너뜀
# 📊 진행률: 598/5385 완료
# 📊 진행률: 599/5385 완료
# 📊 진행률: 600/5385 완료
# 📊 진행률: 601/5385 완료
# 📊 진행률: 602/5385 완료
# 📊 진행률: 603/5385 완료
# 📊 진행률: 604/5385 완료
# 📊 진행률: 605/5385 완료
# 📊 진행률: 606/5385 완료
# 📊 진행률: 607/5385 완료
# 📊 진행률: 608/5385 완료
# 📊 진행률: 609/5385 완료
# 📊 진행률: 610/5385 완료
# 📊 진행률: 611/5385 완료
# 📊 진행률: 612/5385 완료
# 📊 진행률: 613/5385 완료
# 📊 진행률: 614/5385 완료
# 📊 진행률: 615/5385 완료
# 📊 진행률: 616/5385 완료
# 📊 진행률: 617/5385 완료
# 📊 진행률: 618/5385 완료
# 📊 진행률: 619/5385 완료
# 📊 진행률: 620/5385 완료
# 📊 진행률: 621/5385 완료
# 📊 진행률: 622/5385 완료
# 📊 진행률: 623/5385 완료
# 📊 진행률: 624/5385 완료
# 📊 진행률: 625/5385 완료
# ⏭️  benin-semepoji.html - 이미 번역되어 건너뜀
# ⏭️  benin-lokossa.html - 이미 번역되어 건너뜀
# ⏭️  benin-sinaga.html - 이미 번역되어 건너뜀
# ⏭️  benin-soaba.html - 이미 번역되어 건너뜀
# ⏭️  benin-tabast.html - 이미 번역되어 건너뜀
# ⏭️  benin-tanguieta.html - 이미 번역되어 건너뜀
# ⏭️  benin-tekou.html - 이미 번역되어 건너뜀
# ⏭️  benin-teku.html - 이미 번역되어 건너뜀
# ⏭️  benin-teve.html - 이미 번역되어 건너뜀
# ⏭️  benin-toffo.html - 이미 번역되어 건너뜀
# ⏭️  benin-touri.html - 이미 번역되어 건너뜀
# ⏭️  benin-wawa.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-bumthang.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-chirang.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-damchu.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-gasa.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-gedu.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-gelephu.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-ha.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-jakar.html - 이미 번역되어 건너뜀
# ⏭️  benin-seme-podji.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-lungtse.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-mongar.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-paro.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-phuentsholing.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-punakha.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-samdrup-jongkhar.html - 이미 번역되어 건너뜀
# 📊 진행률: 626/5385 완료
# 📊 진행률: 627/5385 완료
# 📊 진행률: 628/5385 완료
# 📊 진행률: 629/5385 완료
# 📊 진행률: 630/5385 완료
# 📊 진행률: 631/5385 완료
# 📊 진행률: 632/5385 완료
# 📊 진행률: 633/5385 완료
# 📊 진행률: 634/5385 완료
# 📊 진행률: 635/5385 완료
# 📊 진행률: 636/5385 완료
# 📊 진행률: 637/5385 완료
# 📊 진행률: 638/5385 완료
# 📊 진행률: 639/5385 완료
# 📊 진행률: 640/5385 완료
# 📊 진행률: 641/5385 완료
# 📊 진행률: 642/5385 완료
# 📊 진행률: 643/5385 완료
# 📊 진행률: 644/5385 완료
# 📊 진행률: 645/5385 완료
# 📊 진행률: 646/5385 완료
# 📊 진행률: 647/5385 완료
# 📊 진행률: 648/5385 완료
# 📊 진행률: 649/5385 완료
# 📊 진행률: 650/5385 완료
# 📊 진행률: 651/5385 완료
# 📊 진행률: 652/5385 완료
# ⏭️  benin-seto.html - 이미 번역되어 건너뜀
# 📊 진행률: 653/5385 완료
# ⏭️  bhutan-sarpang.html - 이미 번역되어 건너뜀
# 📊 진행률: 654/5385 완료
# ⏭️  bhutan-tashiyangtse.html - 이미 번역되어 건너뜀
# 📊 진행률: 655/5385 완료
# ⏭️  bhutan-lhuntse.html - 이미 번역되어 건너뜀
# 📊 진행률: 656/5385 완료
# ⏭️  bhutan-samtse.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-thendhu.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-trongsa.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-thimphu.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-wangdue.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-apolo.html - 이미 번역되어 건너뜀
# ⏭️  bhutan-trashigang.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-cobija.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-cochabamba.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-copacabana.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-guayaramerin.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-lapaz.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-montero.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-oruro.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-potosi.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-beni.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-rurrenabaque.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-samaipata.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-san-ignacio.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-sanborja.html - 이미 번역되어 건너뜀
# 📊 진행률: 657/5385 완료
# 📊 진행률: 658/5385 완료
# 📊 진행률: 659/5385 완료
# 📊 진행률: 660/5385 완료
# 📊 진행률: 661/5385 완료
# 📊 진행률: 662/5385 완료
# 📊 진행률: 663/5385 완료
# 📊 진행률: 664/5385 완료
# 📊 진행률: 665/5385 완료
# 📊 진행률: 666/5385 완료
# 📊 진행률: 667/5385 완료
# 📊 진행률: 668/5385 완료
# 📊 진행률: 669/5385 완료
# 📊 진행률: 670/5385 완료
# 📊 진행률: 671/5385 완료
# 📊 진행률: 672/5385 완료
# 📊 진행률: 673/5385 완료
# 📊 진행률: 674/5385 완료
# 📊 진행률: 675/5385 완료
# 📊 진행률: 676/5385 완료
# ⏭️  bolivia-riberalta.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-santacruz.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-sanjose-chiquitos.html - 이미 번역되어 건너뜀
# 📊 진행률: 677/5385 완료
# 📊 진행률: 678/5385 완료
# 📊 진행률: 679/5385 완료
# ⏭️  bolivia-sucre.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-tarija.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-trinidad.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-uyuni.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-vallegrande.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-banjaluka.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-bihac.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-bijeljina.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-brcko.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-doboj.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-east-sarajevo.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-santa-ana.html - 이미 번역되어 건너뜀
# ⏭️  bolivia-sorata.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-gradiska.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-foca.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-ilidza.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-jablanica.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-jajce.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-kakanj.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-konjic.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-livno.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-ljubuski.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-medjugorje.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-mostar.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-pocitelj.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-prijedor.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-sarajevo.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-srebrenica.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-stolac.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-travnik.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-trebinje.html - 이미 번역되어 건너뜀
# 📊 진행률: 680/5385 완료
# 📊 진행률: 681/5385 완료
# 📊 진행률: 682/5385 완료
# 📊 진행률: 683/5385 완료
# 📊 진행률: 684/5385 완료
# 📊 진행률: 685/5385 완료
# 📊 진행률: 686/5385 완료
# 📊 진행률: 687/5385 완료
# 📊 진행률: 688/5385 완료
# 📊 진행률: 689/5385 완료
# 📊 진행률: 690/5385 완료
# 📊 진행률: 691/5385 완료
# 📊 진행률: 692/5385 완료
# 📊 진행률: 693/5385 완료
# 📊 진행률: 694/5385 완료
# 📊 진행률: 695/5385 완료
# 📊 진행률: 696/5385 완료
# 📊 진행률: 697/5385 완료
# 📊 진행률: 698/5385 완료
# 📊 진행률: 699/5385 완료
# 📊 진행률: 700/5385 완료
# 📊 진행률: 701/5385 완료
# 📊 진행률: 702/5385 완료
# 📊 진행률: 703/5385 완료
# 📊 진행률: 704/5385 완료
# 📊 진행률: 705/5385 완료
# 📊 진행률: 706/5385 완료
# 📊 진행률: 707/5385 완료
# 📊 진행률: 708/5385 완료
# 📊 진행률: 709/5385 완료
# 📊 진행률: 710/5385 완료
# ⏭️  bosnia-gorazde.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-tuzla.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-visegrad.html - 이미 번역되어 건너뜀
# 📊 진행률: 711/5385 완료⏭️  bosnia-umoljani.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-visoko.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-zitomislic.html - 이미 번역되어 건너뜀
# ⏭️  botswana-francistown.html - 이미 번역되어 건너뜀
#
# 📊 진행률: 712/5385 완료
# 📊 진행률: 713/5385 완료
# 📊 진행률: 714/5385 완료
# 📊 진행률: 715/5385 완료
# 📊 진행률: 716/5385 완료
# 📊 진행률: 717/5385 완료
# ⏭️  botswana-bobonong.html - 이미 번역되어 건너뜀
# ⏭️  bosnia-zenica.html - 이미 번역되어 건너뜀
# ⏭️  botswana-kanang.html - 이미 번역되어 건너뜀
# 📊 진행률: 718/5385 완료
# 📊 진행률: 719/5385 완료
# 📊 진행률: 720/5385 완료
# ⏭️  botswana-gumare.html - 이미 번역되어 건너뜀
# 📊 진행률: 721/5385 완료
# ⏭️  botswana-gaborone.html - 이미 번역되어 건너뜀
# 📊 진행률: 722/5385 완료
# ⏭️  botswana-kasane.html - 이미 번역되어 건너뜀
# ⏭️  botswana-leterkene.html - 이미 번역되어 건너뜀
# ⏭️  botswana-mahalapye.html - 이미 번역되어 건너뜀
# ⏭️  botswana-maun.html - 이미 번역되어 건너뜀
# ⏭️  botswana-mochudi.html - 이미 번역되어 건너뜀
# ⏭️  botswana-molepolole.html - 이미 번역되어 건너뜀
# ⏭️  botswana-ramotshwa.html - 이미 번역되어 건너뜀
# ⏭️  botswana-serowe.html - 이미 번역되어 건너뜀
# ⏭️  botswana-lobatse.html - 이미 번역되어 건너뜀
# 📊 진행률: 723/5385 완료
# 📊 진행률: 724/5385 완료
# 📊 진행률: 725/5385 완료
# 📊 진행률: 726/5385 완료
# 📊 진행률: 727/5385 완료
# 📊 진행률: 728/5385 완료
# 📊 진행률: 729/5385 완료
# 📊 진행률: 730/5385 완료
# 📊 진행률: 731/5385 완료
# ⏭️  botswana-tsabong.html - 이미 번역되어 건너뜀
# ⏭️  botswana-shakawe.html - 이미 번역되어 건너뜀
# 📊 진행률: 732/5385 완료
# 📊 진행률: 733/5385 완료
# ⏭️  botswana-tonota.html - 이미 번역되어 건너뜀
# ⏭️  brazil-belem.html - 이미 번역되어 건너뜀
# ⏭️  brazil-belo-horizonte.html - 이미 번역되어 건너뜀
# ⏭️  brazil-campinas.html - 이미 번역되어 건너뜀
# 📊 진행률: 734/5385 완료
# 📊 진행률: 735/5385 완료
# 📊 진행률: 736/5385 완료
# 📊 진행률: 737/5385 완료
# ⏭️  botswana-tutume.html - 이미 번역되어 건너뜀
# 📊 진행률: 738/5385 완료
# ⏭️  brazil-brasilia.html - 이미 번역되어 건너뜀
# 📊 진행률: 739/5385 완료
# ⏭️  brazil-fortaleza.html - 이미 번역되어 건너뜀
# 📊 진행률: 740/5385 완료
# ⏭️  brazil-curitiba.html - 이미 번역되어 건너뜀
# ⏭️  brazil-goiania.html - 이미 번역되어 건너뜀
# ⏭️  brazil-guaruja.html - 이미 번역되어 건너뜀
# ⏭️  brazil-joao-pessoa.html - 이미 번역되어 건너뜀
# ⏭️  brazil-maceio.html - 이미 번역되어 건너뜀
# ⏭️  brazil-campo-grande.html - 이미 번역되어 건너뜀
# ⏭️  brazil-natal.html - 이미 번역되어 건너뜀
# ⏭️  brazil-porto-alegre.html - 이미 번역되어 건너뜀
# 📊 진행률: 741/5385 완료
# 📊 진행률: 742/5385 완료
# 📊 진행률: 743/5385 완료
# 📊 진행률: 744/5385 완료
# 📊 진행률: 745/5385 완료
# 📊 진행률: 746/5385 완료
# 📊 진행률: 747/5385 완료
# 📊 진행률: 748/5385 완료
# ⏭️  brazil-rio.html - 이미 번역되어 건너뜀
# ⏭️  brazil-manaus.html - 이미 번역되어 건너뜀
# ⏭️  brazil-salvador.html - 이미 번역되어 건너뜀
# ⏭️  brazil-sao-luis.html - 이미 번역되어 건너뜀
# ⏭️  brazil-recife.html - 이미 번역되어 건너뜀
# ⏭️  brazil-saopaulo.html - 이미 번역되어 건너뜀
# ⏭️  brazil-teresina.html - 이미 번역되어 건너뜀
# 📊 진행률: 749/5385 완료
# 📊 진행률: 750/5385 완료
# 📊 진행률: 751/5385 완료
# 📊 진행률: 752/5385 완료
# 📊 진행률: 753/5385 완료
# 📊 진행률: 754/5385 완료
# 📊 진행률: 755/5385 완료
# ⏭️  brunei-bandar.html - 이미 번역되어 건너뜀
# ⏭️  brunei-kuala-belait.html - 이미 번역되어 건너뜀
# ⏭️  brunei-seria.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-asenovgrad.html - 이미 번역되어 건너뜀
# 📊 진행률: 756/5385 완료
# 📊 진행률: 757/5385 완료
# 📊 진행률: 758/5385 완료
# 📊 진행률: 759/5385 완료
# ⏭️  brunei-bangar.html - 이미 번역되어 건너뜀
# ⏭️  brazil-sao-goncalo.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-burgas.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-dimitrovgrad.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-dobrich.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-dupnitsa.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-gabrovo.html - 이미 번역되어 건너뜀
# 📊 진행률: 760/5385 완료
# 📊 진행률: 761/5385 완료
# 📊 진행률: 762/5385 완료
# 📊 진행률: 763/5385 완료
# 📊 진행률: 764/5385 완료
# 📊 진행률: 765/5385 완료
# 📊 진행률: 766/5385 완료
# ⏭️  bulgaria-kazanlak.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-blagoevgrad.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-krdzali.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-lovech.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-montana.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-pazardzhik.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-pernik.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-pleven.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-plovdiv.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-ruse.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-shumen.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-silistra.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-sliven.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-sofia.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-stara-zagora.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-targovishte.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-varna.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-veliko-tarnovo.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-vidin.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-banfora.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-bobo-dioulasso.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-dedougou.html - 이미 번역되어 건너뜀
# ⏭️  bulgaria-haskovo.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-diebougou.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-dori.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-gaoua.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-gorom-gorom.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-kaya.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-komsilga.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-koudougou.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-leo.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-manga.html - 이미 번역되어 건너뜀
# 📊 진행률: 767/5385 완료
# 📊 진행률: 768/5385 완료
# 📊 진행률: 769/5385 완료
# 📊 진행률: 770/5385 완료
# 📊 진행률: 771/5385 완료
# 📊 진행률: 772/5385 완료
# 📊 진행률: 773/5385 완료
# 📊 진행률: 774/5385 완료
# 📊 진행률: 775/5385 완료
# 📊 진행률: 776/5385 완료
# 📊 진행률: 777/5385 완료
# 📊 진행률: 778/5385 완료
# 📊 진행률: 779/5385 완료
# 📊 진행률: 780/5385 완료
# 📊 진행률: 781/5385 완료
# 📊 진행률: 782/5385 완료
# 📊 진행률: 783/5385 완료
# 📊 진행률: 784/5385 완료
# 📊 진행률: 785/5385 완료
# 📊 진행률: 786/5385 완료
# 📊 진행률: 787/5385 완료
# 📊 진행률: 788/5385 완료
# 📊 진행률: 789/5385 완료
# 📊 진행률: 790/5385 완료
# 📊 진행률: 791/5385 완료
# 📊 진행률: 792/5385 완료
# 📊 진행률: 793/5385 완료
# 📊 진행률: 794/5385 완료
# 📊 진행률: 795/5385 완료
# 📊 진행률: 796/5385 완료
# 📊 진행률: 797/5385 완료
# 📊 진행률: 798/5385 완료
# ⏭️  burkinafaso-ouagadougou.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-diapaga.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-po.html - 이미 번역되어 건너뜀
# 📊 진행률: 799/5385 완료
# 📊 진행률: 800/5385 완료
# 📊 진행률: 801/5385 완료
# ⏭️  burkinafaso-solenzo.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-ouahigouya.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-tinkale.html - 이미 번역되어 건너뜀
# ⏭️  burkinafaso-yako.html - 이미 번역되어 건너뜀
# ⏭️  burundi-bubanza.html - 이미 번역되어 건너뜀
# ⏭️  burundi-bujumbura.html - 이미 번역되어 건너뜀
# ...
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-bahla.html (172개 요소 번역됨)
# 📊 진행률: 3599/5385 완료
# 🔄 번역 중... oman-duqm.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    ✅ 완료! oman-barka.html (182개 요소 번역됨)
# 📊 진행률: 3600/5385 완료
# 🔄 번역 중... oman-hasim.html
#    🏷️  메타태그 번역: description
#    📊 JSON-LD 데이터 번역 완료
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-buraimi.html (171개 요소 번역됨)
# 🔄 번역 중... oman-ibra.html
# 📊 진행률: 3601/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-duqm.html (171개 요소 번역됨)
# 📊 진행률: 3602/5385 완료
# 🔄 번역 중... oman-ibri.html
#    🏷️  메타태그 번역: description
#    ✅ 완료! oman-hasim.html (183개 요소 번역됨)
# 📊 진행률: 3603/5385 완료
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
# 🔄 번역 중... oman-khasab.html
#    🏷️  메타태그 번역: og:description
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    📊 JSON-LD 데이터 번역 완료
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-ibra.html (182개 요소 번역됨)
# 📊 진행률: 3604/5385 완료
# 🔄 번역 중... oman-masirah.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-khasab.html (171개 요소 번역됨)
# 🔄 번역 중... oman-mudaibi.html
# 📊 진행률: 3605/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-ibri.html (174개 요소 번역됨)
# 📊 진행률: 3606/5385 완료
# 🔄 번역 중... oman-muscat.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-masirah.html (181개 요소 번역됨)
# 📊 진행률: 3607/5385 완료
# 🔄 번역 중... oman-nakhal.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-mudaibi.html (182개 요소 번역됨)
# 📊 진행률: 3608/5385 완료
# 🔄 번역 중... oman-nizwa.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-muscat.html (182개 요소 번역됨)
# 🔄 번역 중... oman-rustaq.html
# 📊 진행률: 3609/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-nakhal.html (172개 요소 번역됨)
# 🔄 번역 중... oman-salalah.html
# 📊 진행률: 3610/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-nizwa.html (171개 요소 번역됨)
# 📊 진행률: 3611/5385 완료
# 🔄 번역 중... oman-samail.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-rustaq.html (182개 요소 번역됨)
# 🔄 번역 중... oman-sinaw.html
# 📊 진행률: 3612/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-samail.html (175개 요소 번역됨)
# 📊 진행률: 3613/5385 완료
# 🔄 번역 중... oman-sohar.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    ✅ 완료! oman-salalah.html (184개 요소 번역됨)
# 📊 진행률: 3614/5385 완료
# 🔄 번역 중... oman-sur.html
#    🏷️  메타태그 번역: og:description
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-sinaw.html (171개 요소 번역됨)
# 🔄 번역 중... oman-wadi-kabir.html
# 📊 진행률: 3615/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-sohar.html (182개 요소 번역됨)
# 📊 진행률: 3616/5385 완료
# 🔄 번역 중... pakistan-abbottabad.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! oman-sur.html (192개 요소 번역됨)
# 📊 진행률: 3617/5385 완료
# 🔄 번역 중... pakistan-bahawalpur.html
#    🏷️  메타태그 번역: description
#    ✅ 완료! oman-wadi-kabir.html (188개 요소 번역됨)
# 📊 진행률: 3618/5385 완료
#    🏷️  메타태그 번역: keywords
# 🔄 번역 중... pakistan-bannu.html
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: og:description
#    🏷️  메타태그 번역: keywords
#    📊 JSON-LD 데이터 번역 완료
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-bahawalpur.html (172개 요소 번역됨)
# 📊 진행률: 3619/5385 완료
# 🔄 번역 중... pakistan-chitral.html
#    ✅ 완료! pakistan-bannu.html (171개 요소 번역됨)
# 📊 진행률: 3620/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
# 🔄 번역 중... pakistan-dera-ismail-khan.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    ✅ 완료! pakistan-abbottabad.html (212개 요소 번역됨)
# 🔄 번역 중... pakistan-faisalabad.html
# 📊 진행률: 3621/5385 완료
#    📊 JSON-LD 데이터 번역 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-faisalabad.html (184개 요소 번역됨)
# 📊 진행률: 3622/5385 완료
# 🔄 번역 중... pakistan-gilgit.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    ✅ 완료! pakistan-dera-ismail-khan.html (190개 요소 번역됨)
# 🔄 번역 중... pakistan-gujranwala.html
# 📊 진행률: 3623/5385 완료
#    📊 JSON-LD 데이터 번역 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-chitral.html (208개 요소 번역됨)
# 🔄 번역 중... pakistan-hyderabad.html
# 📊 진행률: 3624/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-gilgit.html (174개 요소 번역됨)
# 🔄 번역 중... pakistan-islamabad.html
# 📊 진행률: 3625/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    ✅ 완료! pakistan-gujranwala.html (182개 요소 번역됨)
# 📊 진행률: 3626/5385 완료
# 🔄 번역 중... pakistan-jacobabad.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-hyderabad.html (171개 요소 번역됨)
# 🔄 번역 중... pakistan-kanpur.html
# 📊 진행률: 3627/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-jacobabad.html (171개 요소 번역됨)
# 📊 진행률: 3628/5385 완료
# 🔄 번역 중... pakistan-karachi.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-kanpur.html (171개 요소 번역됨)
# 📊 진행률: 3629/5385 완료
# 🔄 번역 중... pakistan-kohat.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-islamabad.html (200개 요소 번역됨)
# 📊 진행률: 3630/5385 완료
# 🔄 번역 중... pakistan-kurram.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-kohat.html (192개 요소 번역됨)
# 🔄 번역 중... pakistan-lahore.html
# 📊 진행률: 3631/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    ✅ 완료! pakistan-karachi.html (202개 요소 번역됨)
# 📊 진행률: 3632/5385 완료
# 🔄 번역 중... pakistan-larkana.html
#    🏷️  메타태그 번역: description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-kurram.html (171개 요소 번역됨)
# 📊 진행률: 3633/5385 완료
#    🏷️  메타태그 번역: keywords
# 🔄 번역 중... pakistan-mardan.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-larkana.html (184개 요소 번역됨)
# 🔄 번역 중... pakistan-mirpurkhas.html
# 📊 진행률: 3634/5385 완료
#    🏷️  메타태그 번역: description
#    ✅ 완료! pakistan-mardan.html (172개 요소 번역됨)
# 📊 진행률: 3635/5385 완료
#    🏷️  메타태그 번역: keywords
# 🔄 번역 중... pakistan-multan.html
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    📊 JSON-LD 데이터 번역 완료
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-lahore.html (203개 요소 번역됨)
# 🔄 번역 중... pakistan-muzaffarabad.html
# 📊 진행률: 3636/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-mirpurkhas.html (171개 요소 번역됨)
# 🔄 번역 중... pakistan-nawabshah.html
# 📊 진행률: 3637/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-muzaffarabad.html (181개 요소 번역됨)
# 📊 진행률: 3638/5385 완료
# 🔄 번역 중... pakistan-peshawar.html
#    ✅ 완료! pakistan-multan.html (195개 요소 번역됨)
# 📊 진행률: 3639/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
# 🔄 번역 중... pakistan-quetta.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    📊 JSON-LD 데이터 번역 완료
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-nawabshah.html (171개 요소 번역됨)
# 📊 진행률: 3640/5385 완료
# 🔄 번역 중... pakistan-rawalpindi.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-quetta.html (172개 요소 번역됨)
# 📊 진행률: 3641/5385 완료
# 🔄 번역 중... pakistan-sargodha.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    ✅ 완료! pakistan-peshawar.html (183개 요소 번역됨)
# 🔄 번역 중... pakistan-sialkot.html
# 📊 진행률: 3642/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    📊 JSON-LD 데이터 번역 완료
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-rawalpindi.html (202개 요소 번역됨)
# 🔄 번역 중... pakistan-sukkur.html
# 📊 진행률: 3643/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-sargodha.html (171개 요소 번역됨)
# 🔄 번역 중... pakistan-swat.html
# 📊 진행률: 3644/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-sialkot.html (183개 요소 번역됨)
# 📊 진행률: 3645/5385 완료
# 🔄 번역 중... pakistan-taxila.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-sukkur.html (171개 요소 번역됨)
# 📊 진행률: 3646/5385 완료
# 🔄 번역 중... pakistan-waziristan.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-swat.html (171개 요소 번역됨)
# 📊 진행률: 3647/5385 완료
# 🔄 번역 중... palau-airai.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-taxila.html (188개 요소 번역됨)
# 📊 진행률: 3648/5385 완료
# 🔄 번역 중... palau-koror.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! pakistan-waziristan.html (183개 요소 번역됨)
# 📊 진행률: 3649/5385 완료
# 🔄 번역 중... palau-melekeok.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! palau-airai.html (179개 요소 번역됨)
# 📊 진행률: 3650/5385 완료
# 🔄 번역 중... palau-ngerulmud.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! palau-koror.html (181개 요소 번역됨)
# 🔄 번역 중... palestine-addahiliya.html
# 📊 진행률: 3651/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! palau-melekeok.html (172개 요소 번역됨)
# 📊 진행률: 3652/5385 완료
# 🔄 번역 중... palestine-albireh.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    ✅ 완료! palau-ngerulmud.html (172개 요소 번역됨)
# 📊 진행률: 3653/5385 완료
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
# 🔄 번역 중... palestine-alzawaida.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    📊 JSON-LD 데이터 번역 완료
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! palestine-addahiliya.html (172개 요소 번역됨)
# 🔄 번역 중... palestine-banisuheila.html
# 📊 진행률: 3654/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! palestine-alzawaida.html (172개 요소 번역됨)
# 🔄 번역 중... palestine-bayt-jala.html
# 📊 진행률: 3655/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! palestine-albireh.html (172개 요소 번역됨)
# 🔄 번역 중... palestine-beit-lahia.html
# 📊 진행률: 3656/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! palestine-banisuheila.html (185개 요소 번역됨)
# 🔄 번역 중... palestine-beithanoun.html
# 📊 진행률: 3657/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! palestine-beit-lahia.html (173개 요소 번역됨)
# 🔄 번역 중... palestine-bethlehem.html
# 📊 진행률: 3658/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    ✅ 완료! palestine-bayt-jala.html (184개 요소 번역됨)
# 📊 진행률: 3659/5385 완료
#    🏷️  메타태그 번역: og:description
# 🔄 번역 중... palestine-deiralbalah.html
#    🏷️  메타태그 번역: description
#    📊 JSON-LD 데이터 번역 완료
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    ✅ 완료! palestine-beithanoun.html (172개 요소 번역됨)
# 🔄 번역 중... palestine-dura.html
# 📊 진행률: 3660/5385 완료
#    📊 JSON-LD 데이터 번역 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! palestine-deiralbalah.html (172개 요소 번역됨)
# 📊 진행률: 3661/5385 완료
# 🔄 번역 중... palestine-gaza.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    ✅ 완료! palestine-bethlehem.html (173개 요소 번역됨)
# 📊 진행률: 3662/5385 완료
#    🏷️  메타태그 번역: og:description
# 🔄 번역 중... palestine-halhul.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    📊 JSON-LD 데이터 번역 완료
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! palestine-dura.html (184개 요소 번역됨)
# 📊 진행률: 3663/5385 완료
# 🔄 번역 중... palestine-hebron.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! palestine-gaza.html (174개 요소 번역됨)
# 🔄 번역 중... palestine-jabalia.html
# 📊 진행률: 3664/5385 완료
#    🏷️  메타태그 번역: description
#    ✅ 완료! palestine-halhul.html (172개 요소 번역됨)
# 📊 진행률: 3665/5385 완료
#    🏷️  메타태그 번역: keywords
# 🔄 번역 중... palestine-jenin.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! palestine-hebron.html (190개 요소 번역됨)
# 🔄 번역 중... palestine-jericho.html
# 📊 진행률: 3666/5385 완료
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    📊 JSON-LD 데이터 번역 완료
#    ✅ 완료! palestine-jabalia.html (172개 요소 번역됨)
# 📊 진행률: 3667/5385 완료
# 🔄 번역 중... palestine-khan-younis.html
#    🏷️  메타태그 번역: description
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
#    ✅ 완료! palestine-jenin.html (171개 요소 번역됨)
# 📊 진행률: 3668/5385 완료
# 🔄 번역 중... palestine-nablus.html
#    🏷️  메타태그 번역: description
#    📊 JSON-LD 데이터 번역 완료
#    🏷️  메타태그 번역: keywords
#    🏷️  메타태그 번역: og:title
#    🏷️  메타태그 번역: og:description
